# %%
import os, random, glob, sys
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

torch.set_printoptions(threshold=sys.maxsize)
torch.set_printoptions(linewidth=sys.maxsize)

np.set_printoptions(threshold=sys.maxsize)
np.set_printoptions(linewidth=sys.maxsize)

from core.model.Unet import UNet_2D_128
from core.utils.utils import import_mapf_instance, inverse_sigmoid, get_scene_80, get_sum_of_cost, get_cbs_result, visualize_heatmap
from core.func.cbs_basic import CBSSolver, CBSSolver_Cost_Plot, CBSSolver_Cost
from core.func.icbs_complete import ICBS_Solver_Compare

# %%
def dense_input_data(starts, goals):
    input_data = []

    all_data = [(sx, sy, gx, gy) for (sx, sy), (gx, gy) in zip(starts, goals)]

    for i, (start, goal) in enumerate(zip(starts, goals)):
        sx, sy = start
        gx, gy = goal
        dx, dy = gx-sx, gy-sy
        mag = np.sqrt(dx ** 2 + dy ** 2)

        if mag != 0:
            dx = dx / mag
            dy = dy / mag

        except_agent_data = all_data[:i] + all_data[i+1:]

        own_data = [sx, sy, gx, gy, dx, dy, mag]

        for (other_sx, other_sy, other_gx, other_gy) in except_agent_data:
            other_dx, other_dy = other_gx-other_sx, other_gy-other_sy
            other_mag = np.sqrt(other_dx ** 2 + other_dy ** 2)

            if other_mag != 0:
                other_dx = other_dx / other_mag
                other_dy = other_dy / other_mag

            own_data += [other_sx-sx, other_sy-sy, other_dx, other_dy, other_mag]

        own_data = np.array(own_data)
        input_data.append(own_data)
    
    return np.array(input_data)

# %% [markdown]
# Sorted_Normalized_no_vertex

# %%
train_scene_list = get_scene_80("test_69", 'bigger_heatmap', dataset='train')
test_scene_list = get_scene_80("test_69", "bigger_heatmap", dataset="test")
method = "bigger_heatmap"
device = "cuda:0" if torch.cuda.is_available() else 'cpu'
print("device: {}".format(device))
# Out:
# Total 1949 data loaded for train!
# Total 244 data loaded for test!
# device: cuda:0

# %%
model = UNet_2D_128(2, 1, 102)
# model = cnn_mlp_64(102, 4096)
mseloss = nn.MSELoss()

model_name = "unet_128"
loss_name = mseloss._get_name()

# /home/railab/Workspace/CCBS/code/model_params/unet/MSELoss/L2_None/batch_32_lr_0.0001_epoch_1.pt
save_path = "/home/railab/Workspace/CCBS/code/model_params/{}/{}/L2_None".format(model_name, loss_name)

if os.path.exists(save_path):
    saved_model_list = glob.glob(save_path + "/batch*")
    saved_model_list.sort(key= lambda x : int(x.split("_")[-1][:-4]))
    last_model_file_name = saved_model_list[-1]
    previous_epochs = int(last_model_file_name.split("_")[-1][:-4])
else:
    previous_epochs = 0
    loss_list = []
    print("There is no trained model!")

print("Model: {}\nLoss: {}\n".format(model_name, loss_name))
# Out:
# Model: unet_128
# Loss: MSELoss

# %%
model.load_state_dict(torch.load(last_model_file_name))

# %%
avg_loss = 0.
model.eval()

for i, scene in enumerate(test_scene_list):
    # if "27104" not in scene:
    #     continue

    # Get data
    test_name = scene.split("/")[-2]
    scene_name = scene.split("/")[-1][:-4]

    total_result_file_name = "/home/railab/Workspace/CCBS/Train_results/Overfitting_test_69/cbs_results/bigger_heatmap/" + scene_name + ".txt"

    if os.path.exists(total_result_file_name):
        continue

    map, starts, goals = import_mapf_instance(scene)
    agent_num = len(starts)

    obs_map = np.array([[int(val) for val in sublist] for sublist in map])
    obs_map = np.repeat(obs_map[np.newaxis,:,:], agent_num, axis=0)

    heatmap_path = "/home/railab/Workspace/CCBS/code/costmaps/Gaussian_Blur/{}_heatmap/bigger_heatmap/{}.npy".format(test_name, scene_name)
    heatmap_data = np.load(heatmap_path, allow_pickle=True)

    h_map_path = "/home/railab/Workspace/CCBS/code/h_value_maps/{}/bigger_heatmap/{}.npy".format(test_name, scene_name)
    h_map_array = np.load(h_map_path, allow_pickle=True)

    input_data = dense_input_data(np.array(starts), np.array(goals))

    obs_map = torch.reshape(torch.Tensor(obs_map), heatmap_data.shape)
    h_val_map = torch.reshape(torch.Tensor(h_map_array), heatmap_data.shape)

    conv_data = torch.cat((obs_map, h_val_map), axis=1)

    input_data = torch.Tensor(input_data)

    pred = model(conv_data, input_data)
    pred = torch.reshape(pred, heatmap_data.shape)
    pred = torch.sigmoid(pred)
    # loss = mseloss(pred, torch.Tensor(heatmap_data))
    # print(loss)

    pred = pred.detach().numpy()

    pred = np.where(pred<1e-3, 0, pred)

    # print(pred)
    # print(heatmap_data)

    # print(pred.shape)
    # print(heatmap_data.shape)

    
    # /home/railab/Workspace/CCBS/code/instances/gen_test/test_69
    result_file_path = "/home/railab/Workspace/CCBS/code/instances/gen_test/{}/{}.txt".format(test_name, scene_name)
    print("==============================================================")
    print("Scene: {}".format(scene_name))

    f = open(result_file_path, 'r')
    contents = f.readlines()
    cbs_result = contents[1] + contents[2].rstrip()
    f.close()

    print("CBS " + contents[2].split(", ")[-1])
    
    # cbs_gen_nodes = int(contents[2].split(", ")[1].split(": ")[1])
    # cbs_exp_nodes = int(contents[2].split(", ")[2].split(": ")[1])

    # target_solver = CBSSolver_Cost(map, starts, goals, heatmap_data)
    # target_path, target_gen_nodes, target_exp_nodes, target_total_CT = target_solver.find_solution()
    # target_cost = get_sum_of_cost(target_path)

    # target_result = "\nTarget results!\nCost: {}, Gen_nodes: {}, Exp_nodes: {}, Total CT: {}".format(target_cost, target_gen_nodes, target_exp_nodes, target_total_CT)
    # print(target_result)

    # visualize_heatmap(heatmap_data, "target")
    # visualize_heatmap(pred, 'pred')

    l_cbs_solver = CBSSolver_Cost(map, starts, goals, pred)
    l_cbs_path, l_cbs_gen_nodes, l_cbs_exp_nodes, l_cbs_total_CT = l_cbs_solver.find_solution()

    if l_cbs_path != None:

        l_cbs_cost = get_sum_of_cost(l_cbs_path)

        l_cbs_result = "\nLearned_CBS results!\nCost: {}, Gen_nodes: {}, Exp_nodes: {}, Total CT: {}\n".format(l_cbs_cost, l_cbs_gen_nodes, l_cbs_exp_nodes, l_cbs_total_CT)
        total_result = "".join(contents) + l_cbs_result
        print(total_result)

        total_result_file_name = "/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/" + scene_name + ".txt"
        f = open(total_result_file_name, "w")
        f.write(total_result)
        f.close()
    else:
        continue
# Out:
# ==============================================================
# Scene: test_69_86101
# CBS total CT: 5.124590158462524
#
# test_69_86101
# CBS result!
# Cost: 1465, Gen nodes: 19, Exp nodes: 10, total CT: 5.124590158462524
# ICBS result!
# Cost: 1465, Gen nodes: 16, Exp nodes: 10, total CT: 19.65598702430725
# Learned_CBS results!
# Cost: 1465, Gen_nodes: 5, Exp_nodes: 3, Total CT: 0.6674354076385498
#
# ==============================================================
# Scene: test_69_88837
# CBS total CT: 52.11671996116638
#
# test_69_88837
# CBS result!
# Cost: 1736, Gen nodes: 383, Exp nodes: 192, total CT: 52.11671996116638
# ICBS result!
# Cost: 1736, Gen nodes: 16, Exp nodes: 10, total CT: 11.23190188407898
# Learned_CBS results!
# Cost: 1736, Gen_nodes: 783, Exp_nodes: 392, Total CT: 40.24347543716431
#
# ==============================================================
# Scene: test_69_85718
# CBS total CT: 4.6101555824279785
#
# test_69_85718
# CBS result!
# Cost: 1770, Gen nodes: 23, Exp nodes: 12, total CT: 4.6101555824279785
# ICBS result!
# Cost: 1770, Gen nodes: 12, Exp nodes: 9, total CT: 26.516393423080444
# Learned_CBS results!
# Cost: 1770, Gen_nodes: 11, Exp_nodes: 6, Total CT: 13.666165351867676
#
# ==============================================================
# Scene: test_69_81438
# CBS total CT: 26.437381744384766
#
# test_69_81438
# CBS result!
# Cost: 1727, Gen nodes: 309, Exp nodes: 155, total CT: 26.437381744384766
# ICBS result!
# Cost: 1727, Gen nodes: 129, Exp nodes: 66, total CT: 35.46863794326782
# Learned_CBS results!
# Cost: 1727, Gen_nodes: 3, Exp_nodes: 2, Total CT: 0.532480001449585
#
# ==============================================================
# Scene: test_69_89176
# CBS total CT: 39.74498271942139
#
# test_69_89176
# CBS result!
# Cost: 1713, Gen nodes: 55, Exp nodes: 28, total CT: 39.74498271942139
# ICBS result!
# Cost: 1713, Gen nodes: 10, Exp nodes: 8, total CT: 87.2295982837677
# Learned_CBS results!
# Cost: 1713, Gen_nodes: 11, Exp_nodes: 6, Total CT: 2.016629219055176
#
# ==============================================================
# Scene: test_69_89186
# CBS total CT: 16.585092306137085
#
# test_69_89186
# CBS result!
# Cost: 1826, Gen nodes: 203, Exp nodes: 102, total CT: 16.585092306137085
# ICBS result!
# Cost: 1826, Gen nodes: 114, Exp nodes: 58, total CT: 26.494974851608276
# Learned_CBS results!
# Cost: 1826, Gen_nodes: 35, Exp_nodes: 18, Total CT: 3.3117012977600098
#
# ==============================================================
# Scene: test_69_84355
# CBS total CT: 20.44455575942993
#
# test_69_84355
# CBS result!
# Cost: 1529, Gen nodes: 265, Exp nodes: 133, total CT: 20.44455575942993
# ICBS result!
# Cost: 1529, Gen nodes: 132, Exp nodes: 69, total CT: 44.25945854187012
# Learned_CBS results!
# Cost: 1529, Gen_nodes: 1, Exp_nodes: 1, Total CT: 0.35791802406311035
#
# ==============================================================
# Scene: test_69_82080
# CBS total CT: 25.8406822681427
#
# test_69_82080
# CBS result!
# Cost: 1639, Gen nodes: 1219, Exp nodes: 610, total CT: 25.8406822681427
# ICBS result!
# Cost: 1639, Gen nodes: 88, Exp nodes: 46, total CT: 30.769216775894165
# Learned_CBS results!
# Cost: 1639, Gen_nodes: 2511, Exp_nodes: 1256, Total CT: 31.984017610549927
#
# ==============================================================
# Scene: test_69_80873
# CBS total CT: 11.881459951400757
#
# test_69_80873
# CBS result!
# Cost: 1942, Gen nodes: 65, Exp nodes: 33, total CT: 11.881459951400757
# ICBS result!
# Cost: 1942, Gen nodes: 21, Exp nodes: 15, total CT: 156.92118954658508
# Learned_CBS results!
# Cost: 1942, Gen_nodes: 1, Exp_nodes: 1, Total CT: 0.7390141487121582
#
# ==============================================================
# Scene: test_69_87069
# CBS total CT: 49.17098951339722
#
# test_69_87069
# CBS result!
# Cost: 1922, Gen nodes: 939, Exp nodes: 470, total CT: 49.17098951339722
# ICBS result!
# Cost: 1922, Gen nodes: 18, Exp nodes: 12, total CT: 55.170835971832275
# Learned_CBS results!
# Cost: 1922, Gen_nodes: 1193, Exp_nodes: 597, Total CT: 28.32105565071106
#
# ==============================================================
# Scene: test_69_82077
# CBS total CT: 33.48153758049011
#
# test_69_82077
# CBS result!
# Cost: 1446, Gen nodes: 121, Exp nodes: 61, total CT: 33.48153758049011
# ICBS result!
# Cost: 1446, Gen nodes: 85, Exp nodes: 45, total CT: 134.74295711517334
# Learned_CBS results!
# Cost: 1446, Gen_nodes: 1, Exp_nodes: 1, Total CT: 0.352215051651001
#
# ==============================================================
# Scene: test_69_83441
# CBS total CT: 269.29822516441345
#
# test_69_83441
# CBS result!
# Cost: 1718, Gen nodes: 1481, Exp nodes: 741, total CT: 269.29822516441345
# ICBS result!
# Cost: 1718, Gen nodes: 1475, Exp nodes: 741, total CT: 2400.7133328914642
# Learned_CBS results!
# Cost: 1718, Gen_nodes: 9, Exp_nodes: 5, Total CT: 14.438281297683716
#
# ==============================================================
# Scene: test_69_88459
# CBS total CT: 26.113030910491943
#
# test_69_88459
# CBS result!
# Cost: 1702, Gen nodes: 73, Exp nodes: 37, total CT: 26.113030910491943
# ICBS result!
# Cost: 1702, Gen nodes: 11, Exp nodes: 8, total CT: 20.639023065567017
# Learned_CBS results!
# Cost: 1702, Gen_nodes: 5, Exp_nodes: 3, Total CT: 1.5104808807373047
#
# ==============================================================
# Scene: test_69_84811
# CBS total CT: 7.020216226577759
#
# test_69_84811
# CBS result!
# Cost: 1678, Gen nodes: 95, Exp nodes: 48, total CT: 7.020216226577759
# ICBS result!
# Cost: 1678, Gen nodes: 15, Exp nodes: 9, total CT: 21.910866498947144
# Learned_CBS results!
# Cost: 1678, Gen_nodes: 57, Exp_nodes: 29, Total CT: 2.2881276607513428
#
# ==============================================================
# Scene: test_69_88782
# CBS total CT: 4.902858734130859
#
# test_69_88782
# CBS result!
# Cost: 1544, Gen nodes: 19, Exp nodes: 10, total CT: 4.902858734130859
# ICBS result!
# Cost: 1544, Gen nodes: 16, Exp nodes: 10, total CT: 12.413362264633179
# Learned_CBS results!
# Cost: 1544, Gen_nodes: 513, Exp_nodes: 257, Total CT: 33.255823373794556
#
# ==============================================================
# Scene: test_69_81069
# CBS total CT: 1.3605101108551025
#
# test_69_81069
# CBS result!
# Cost: 1736, Gen nodes: 19, Exp nodes: 10, total CT: 1.3605101108551025
# ICBS result!
# Cost: 1736, Gen nodes: 18, Exp nodes: 11, total CT: 9.966552257537842
# Learned_CBS results!
# Cost: 1736, Gen_nodes: 7, Exp_nodes: 4, Total CT: 6.220038414001465
#
# ==============================================================
# Scene: test_69_86113
# CBS total CT: 12.721236228942871
#
# test_69_86113
# CBS result!
# Cost: 1616, Gen nodes: 49, Exp nodes: 25, total CT: 12.721236228942871
# ICBS result!
# Cost: 1616, Gen nodes: 15, Exp nodes: 10, total CT: 23.380680322647095
# Learned_CBS results!
# Cost: 1616, Gen_nodes: 47, Exp_nodes: 24, Total CT: 2.093569040298462
#
# ==============================================================
# Scene: test_69_86320
# CBS total CT: 1.940661907196045
#
# test_69_86320
# CBS result!
# Cost: 1484, Gen nodes: 27, Exp nodes: 14, total CT: 1.940661907196045
# ICBS result!
# Cost: 1484, Gen nodes: 16, Exp nodes: 9, total CT: 3.1675631999969482
# Learned_CBS results!
# Cost: 1484, Gen_nodes: 13, Exp_nodes: 7, Total CT: 1.6989102363586426
#
# ==============================================================
# Scene: test_69_89325
# CBS total CT: 234.26749730110168
#
# test_69_89325
# CBS result!
# Cost: 1679, Gen nodes: 203, Exp nodes: 102, total CT: 234.26749730110168
# ICBS result!
# Cost: 1679, Gen nodes: 9, Exp nodes: 7, total CT: 36.49306917190552
# Learned_CBS results!
# Cost: 1679, Gen_nodes: 7, Exp_nodes: 4, Total CT: 6.559280872344971
#
# ==============================================================
# Scene: test_69_83912
# CBS total CT: 172.2906949520111
#
# test_69_83912
# CBS result!
# Cost: 1656, Gen nodes: 219, Exp nodes: 110, total CT: 172.2906949520111
# ICBS result!
# Cost: 1656, Gen nodes: 9, Exp nodes: 7, total CT: 17.255205154418945
# Learned_CBS results!
# Cost: 1656, Gen_nodes: 277, Exp_nodes: 139, Total CT: 73.9178454875946
#
# ==============================================================
# Scene: test_69_84513
# CBS total CT: 50.242865324020386
#
# test_69_84513
# CBS result!
# Cost: 1792, Gen nodes: 515, Exp nodes: 258, total CT: 50.242865324020386
# ICBS result!
# Cost: 1792, Gen nodes: 258, Exp nodes: 131, total CT: 228.91276574134827
# Learned_CBS results!
# Cost: 1792, Gen_nodes: 7, Exp_nodes: 4, Total CT: 8.609192848205566
#
# ==============================================================
# Scene: test_69_80453
# CBS total CT: 7.194906711578369
#
# test_69_80453
# CBS result!
# Cost: 1484, Gen nodes: 77, Exp nodes: 39, total CT: 7.194906711578369
# ICBS result!
# Cost: 1484, Gen nodes: 17, Exp nodes: 11, total CT: 17.701810359954834
# Learned_CBS results!
# Cost: 1484, Gen_nodes: 11, Exp_nodes: 6, Total CT: 0.626878023147583
#
# ==============================================================
# Scene: test_69_82235
# CBS total CT: 18.618348360061646
#
# test_69_82235
# CBS result!
# Cost: 1694, Gen nodes: 201, Exp nodes: 101, total CT: 18.618348360061646
# ICBS result!
# Cost: 1694, Gen nodes: 101, Exp nodes: 53, total CT: 30.50447416305542
# Learned_CBS results!
# Cost: 1694, Gen_nodes: 1, Exp_nodes: 1, Total CT: 0.7182886600494385
#
# ==============================================================
# Scene: test_69_84897
# CBS total CT: 67.36415767669678
#
# test_69_84897
# CBS result!
# Cost: 1835, Gen nodes: 1103, Exp nodes: 552, total CT: 67.36415767669678
# ICBS result!
# Cost: 1835, Gen nodes: 92, Exp nodes: 49, total CT: 93.59222412109375
# Learned_CBS results!
# Cost: 1835, Gen_nodes: 883, Exp_nodes: 442, Total CT: 20.58953309059143
#
# ==============================================================
# Scene: test_69_83549
# CBS total CT: 19.783312797546387
#
# test_69_83549
# CBS result!
# Cost: 1621, Gen nodes: 45, Exp nodes: 23, total CT: 19.783312797546387
# ICBS result!
# Cost: 1621, Gen nodes: 9, Exp nodes: 7, total CT: 18.77631402015686
# Learned_CBS results!
# Cost: 1621, Gen_nodes: 5, Exp_nodes: 3, Total CT: 2.1077795028686523
#
# ==============================================================
# Scene: test_69_80961
# CBS total CT: 9.90387225151062
#
# test_69_80961
# CBS result!
# Cost: 1642, Gen nodes: 29, Exp nodes: 15, total CT: 9.90387225151062
# ICBS result!
# Cost: 1642, Gen nodes: 18, Exp nodes: 12, total CT: 58.929856300354004
# Learned_CBS results!
# Cost: 1642, Gen_nodes: 3, Exp_nodes: 2, Total CT: 0.9206793308258057
#
# ==============================================================
# Scene: test_69_86709
# CBS total CT: 4.1355202198028564
#
# test_69_86709
# CBS result!
# Cost: 1629, Gen nodes: 45, Exp nodes: 23, total CT: 4.1355202198028564
# ICBS result!
# Cost: 1629, Gen nodes: 33, Exp nodes: 18, total CT: 13.187118768692017
# Learned_CBS results!
# Cost: 1629, Gen_nodes: 7, Exp_nodes: 4, Total CT: 0.8483865261077881
#
# ==============================================================
# Scene: test_69_84799
# CBS total CT: 18.982508182525635
#
# test_69_84799
# CBS result!
# Cost: 1625, Gen nodes: 71, Exp nodes: 36, total CT: 18.982508182525635
# ICBS result!
# Cost: 1625, Gen nodes: 10, Exp nodes: 8, total CT: 33.76659941673279
# Learned_CBS results!
# Cost: 1625, Gen_nodes: 13, Exp_nodes: 7, Total CT: 0.9212944507598877
#
# ==============================================================
# Scene: test_69_81475
# CBS total CT: 11.411264657974243
#
# test_69_81475
# CBS result!
# Cost: 1789, Gen nodes: 149, Exp nodes: 75, total CT: 11.411264657974243
# ICBS result!
# Cost: 1789, Gen nodes: 52, Exp nodes: 28, total CT: 19.16969895362854
# Learned_CBS results!
# Cost: 1789, Gen_nodes: 37, Exp_nodes: 19, Total CT: 7.277888298034668
#
# ==============================================================
# Scene: test_69_80443
# CBS total CT: 2.8783934116363525
#
# test_69_80443
# CBS result!
# Cost: 1740, Gen nodes: 65, Exp nodes: 33, total CT: 2.8783934116363525
# ICBS result!
# Cost: 1740, Gen nodes: 64, Exp nodes: 33, total CT: 5.314190626144409
# Learned_CBS results!
# Cost: 1740, Gen_nodes: 7, Exp_nodes: 4, Total CT: 14.260566234588623
#
# ==============================================================
# Scene: test_69_89815
# CBS total CT: 5.593696117401123
#
# test_69_89815
# CBS result!
# Cost: 1547, Gen nodes: 69, Exp nodes: 35, total CT: 5.593696117401123
# ICBS result!
# Cost: 1547, Gen nodes: 35, Exp nodes: 20, total CT: 27.96642804145813
# Learned_CBS results!
# Cost: 1547, Gen_nodes: 67, Exp_nodes: 34, Total CT: 2.624229669570923
#
# ==============================================================
# Scene: test_69_82488
# CBS total CT: 5.728084087371826
#
# test_69_82488
# CBS result!
# Cost: 1673, Gen nodes: 31, Exp nodes: 16, total CT: 5.728084087371826
# ICBS result!
# Cost: 1673, Gen nodes: 29, Exp nodes: 16, total CT: 13.044788599014282
# Learned_CBS results!
# Cost: 1673, Gen_nodes: 5, Exp_nodes: 3, Total CT: 0.709545373916626
#
# ==============================================================
# Scene: test_69_86145
# CBS total CT: 34.688714027404785
#
# test_69_86145
# CBS result!
# Cost: 1710, Gen nodes: 519, Exp nodes: 260, total CT: 34.688714027404785
# ICBS result!
# Cost: 1710, Gen nodes: 259, Exp nodes: 133, total CT: 99.19833040237427
# Learned_CBS results!
# Cost: 1710, Gen_nodes: 149, Exp_nodes: 75, Total CT: 3.8699188232421875
#
# ==============================================================
# Scene: test_69_82566
# CBS total CT: 3.844503879547119
#
# test_69_82566
# CBS result!
# Cost: 1620, Gen nodes: 33, Exp nodes: 17, total CT: 3.844503879547119
# ICBS result!
# Cost: 1620, Gen nodes: 31, Exp nodes: 17, total CT: 19.105920791625977
# Learned_CBS results!
# Cost: 1620, Gen_nodes: 3, Exp_nodes: 2, Total CT: 0.47289061546325684
#
# ==============================================================
# Scene: test_69_88740
# CBS total CT: 1.4399170875549316
#
# test_69_88740
# CBS result!
# Cost: 1831, Gen nodes: 29, Exp nodes: 15, total CT: 1.4399170875549316
# ICBS result!
# Cost: 1831, Gen nodes: 15, Exp nodes: 9, total CT: 2.814085006713867
# Learned_CBS results!
# Cost: 1831, Gen_nodes: 1, Exp_nodes: 1, Total CT: 0.7425315380096436
#
# ==============================================================
# Scene: test_69_87724
# CBS total CT: 122.14165735244751
#
# test_69_87724
# CBS result!
# Cost: 1800, Gen nodes: 1413, Exp nodes: 707, total CT: 122.14165735244751
# ICBS result!
# Cost: 1800, Gen nodes: 53, Exp nodes: 28, total CT: 12.32758116722107
# Learned_CBS results!
# Cost: 1800, Gen_nodes: 95, Exp_nodes: 48, Total CT: 2.8257834911346436
#
# ==============================================================
# Scene: test_69_81335
# CBS total CT: 5.568873405456543
#
# test_69_81335
# CBS result!
# Cost: 1481, Gen nodes: 37, Exp nodes: 19, total CT: 5.568873405456543
# ICBS result!
# Cost: 1481, Gen nodes: 34, Exp nodes: 19, total CT: 19.173205375671387
# Learned_CBS results!
# Cost: 1481, Gen_nodes: 7, Exp_nodes: 4, Total CT: 2.037492036819458
#
# ==============================================================
# Scene: test_69_85498
# CBS total CT: 4.288541316986084
#
# test_69_85498
# CBS result!
# Cost: 1947, Gen nodes: 35, Exp nodes: 18, total CT: 4.288541316986084
# ICBS result!
# Cost: 1947, Gen nodes: 11, Exp nodes: 8, total CT: 9.206992626190186
# Learned_CBS results!
# Cost: 1947, Gen_nodes: 15, Exp_nodes: 8, Total CT: 1.0973999500274658
#
# ==============================================================
# Scene: test_69_85582
# CBS total CT: 11.269681215286255
#
# test_69_85582
# CBS result!
# Cost: 1662, Gen nodes: 103, Exp nodes: 52, total CT: 11.269681215286255
# ICBS result!
# Cost: 1662, Gen nodes: 50, Exp nodes: 26, total CT: 19.578622579574585
# Learned_CBS results!
# Cost: 1662, Gen_nodes: 3, Exp_nodes: 2, Total CT: 0.6007416248321533
#
# ==============================================================
# Scene: test_69_82976
# CBS total CT: 81.87080001831055
#
# test_69_82976
# CBS result!
# Cost: 1819, Gen nodes: 1027, Exp nodes: 514, total CT: 81.87080001831055
# ICBS result!
# Cost: 1819, Gen nodes: 1025, Exp nodes: 514, total CT: 756.864129781723
# Learned_CBS results!
# Cost: 1819, Gen_nodes: 3, Exp_nodes: 2, Total CT: 0.8034727573394775
#
# ==============================================================
# Scene: test_69_82660
# CBS total CT: 10.95179796218872
#
# test_69_82660
# CBS result!
# Cost: 2244, Gen nodes: 51, Exp nodes: 26, total CT: 10.95179796218872
# ICBS result!
# Cost: 2244, Gen nodes: 18, Exp nodes: 13, total CT: 109.11745572090149
# Learned_CBS results!
# Cost: 2244, Gen_nodes: 9, Exp_nodes: 5, Total CT: 1.3154292106628418
#
# ==============================================================
# Scene: test_69_81387
# CBS total CT: 9.901317119598389
#
# test_69_81387
# CBS result!
# Cost: 1611, Gen nodes: 63, Exp nodes: 32, total CT: 9.901317119598389
# ICBS result!
# Cost: 1611, Gen nodes: 61, Exp nodes: 32, total CT: 23.3989737033844
# Learned_CBS results!
# Cost: 1611, Gen_nodes: 3, Exp_nodes: 2, Total CT: 1.2151479721069336
#
# ==============================================================
# Scene: test_69_81567
# CBS total CT: 30.583380460739136
#
# test_69_81567
# CBS result!
# Cost: 1687, Gen nodes: 59, Exp nodes: 30, total CT: 30.583380460739136
# ICBS result!
# Cost: 1687, Gen nodes: 56, Exp nodes: 32, total CT: 144.31717228889465
# Learned_CBS results!
# Cost: 1687, Gen_nodes: 45, Exp_nodes: 23, Total CT: 4.347660779953003
#
# ==============================================================
# Scene: test_69_82938
# CBS total CT: 24.663474559783936
#
# test_69_82938
# CBS result!
# Cost: 1937, Gen nodes: 151, Exp nodes: 76, total CT: 24.663474559783936
# ICBS result!
# Cost: 1937, Gen nodes: 30, Exp nodes: 17, total CT: 26.037452459335327
# Learned_CBS results!
# Cost: 1937, Gen_nodes: 5, Exp_nodes: 3, Total CT: 1.1120057106018066
#
# ==============================================================
# Scene: test_69_88722
# CBS total CT: 1.5846993923187256
#
# test_69_88722
# CBS result!
# Cost: 1869, Gen nodes: 41, Exp nodes: 21, total CT: 1.5846993923187256
# ICBS result!
# Cost: 1869, Gen nodes: 15, Exp nodes: 9, total CT: 5.159567594528198
# Learned_CBS results!
# Cost: 1869, Gen_nodes: 5, Exp_nodes: 3, Total CT: 5.788249969482422
#
# ==============================================================
# Scene: test_69_88185
# CBS total CT: 8.312418222427368
#
# test_69_88185
# CBS result!
# Cost: 1668, Gen nodes: 35, Exp nodes: 18, total CT: 8.312418222427368
# ICBS result!
# Cost: 1668, Gen nodes: 32, Exp nodes: 18, total CT: 23.159193754196167
# Learned_CBS results!
# Cost: 1668, Gen_nodes: 3, Exp_nodes: 2, Total CT: 0.6840317249298096
#
# ==============================================================
# Scene: test_69_87554
# CBS total CT: 28.650248765945435
#
# test_69_87554
# CBS result!
# Cost: 1780, Gen nodes: 621, Exp nodes: 311, total CT: 28.650248765945435
# ICBS result!
# Cost: 1780, Gen nodes: 90, Exp nodes: 47, total CT: 29.63930892944336
# Learned_CBS results!
# Cost: 1780, Gen_nodes: 447, Exp_nodes: 224, Total CT: 8.922710657119751
#
# ==============================================================
# Scene: test_69_80544
# CBS total CT: 3.680860996246338
#
# test_69_80544
# CBS result!
# Cost: 1497, Gen nodes: 91, Exp nodes: 46, total CT: 3.680860996246338
# ICBS result!
# Cost: 1497, Gen nodes: 90, Exp nodes: 46, total CT: 10.388673782348633
# Learned_CBS results!
# Cost: 1497, Gen_nodes: 9, Exp_nodes: 5, Total CT: 0.9260909557342529
#
# ==============================================================
# Scene: test_69_87477
# CBS total CT: 29.244985342025757
#
# test_69_87477
# CBS result!
# Cost: 1710, Gen nodes: 75, Exp nodes: 38, total CT: 29.244985342025757
# ICBS result!
# Cost: 1710, Gen nodes: 69, Exp nodes: 38, total CT: 149.1054892539978
# Learned_CBS results!
# Cost: 1710, Gen_nodes: 3, Exp_nodes: 2, Total CT: 0.8310947418212891
#
# ==============================================================
# Scene: test_69_89914
# CBS total CT: 13.458775281906128
#
# test_69_89914
# CBS result!
# Cost: 1580, Gen nodes: 33, Exp nodes: 17, total CT: 13.458775281906128
# ICBS result!
# Cost: 1580, Gen nodes: 8, Exp nodes: 6, total CT: 9.738057613372803
# Learned_CBS results!
# Cost: 1580, Gen_nodes: 7, Exp_nodes: 4, Total CT: 2.163670539855957
#
# ==============================================================
# Scene: test_69_83256
# CBS total CT: 64.58047890663147
#
# test_69_83256
# CBS result!
# Cost: 1530, Gen nodes: 1569, Exp nodes: 785, total CT: 64.58047890663147
# ICBS result!
# Cost: 1530, Gen nodes: 16, Exp nodes: 10, total CT: 3.470445394515991
# Learned_CBS results!
# Cost: 1530, Gen_nodes: 29, Exp_nodes: 15, Total CT: 1.9516198635101318
#
# ==============================================================
# Scene: test_69_81433
# CBS total CT: 51.002620220184326
#
# test_69_81433
# CBS result!
# Cost: 1783, Gen nodes: 1111, Exp nodes: 556, total CT: 51.002620220184326
# ICBS result!
# Cost: 1783, Gen nodes: 91, Exp nodes: 48, total CT: 17.893673181533813
# Learned_CBS results!
# Cost: 1783, Gen_nodes: 197, Exp_nodes: 99, Total CT: 8.573698043823242
#
# ==============================================================
# Scene: test_69_85291
# CBS total CT: 12.092885255813599
#
# test_69_85291
# CBS result!
# Cost: 1482, Gen nodes: 23, Exp nodes: 12, total CT: 12.092885255813599
# ICBS result!
# Cost: 1482, Gen nodes: 7, Exp nodes: 5, total CT: 4.6100194454193115
# Learned_CBS results!
# Cost: 1482, Gen_nodes: 5, Exp_nodes: 3, Total CT: 0.5834646224975586
#
# ==============================================================
# Scene: test_69_81465
# CBS total CT: 146.53057432174683
#
# test_69_81465
# CBS result!
# Cost: 2118, Gen nodes: 1003, Exp nodes: 502, total CT: 146.53057432174683
# ICBS result!
# Cost: 2118, Gen nodes: 25, Exp nodes: 15, total CT: 27.36703109741211
# Learned_CBS results!
# Cost: 2118, Gen_nodes: 7, Exp_nodes: 4, Total CT: 1.0093324184417725
#
# ==============================================================
# Scene: test_69_88851
# CBS total CT: 44.68755078315735
#
# test_69_88851
# CBS result!
# Cost: 1896, Gen nodes: 35, Exp nodes: 18, total CT: 44.68755078315735
# ICBS result!
# Cost: 1896, Gen nodes: 7, Exp nodes: 5, total CT: 20.69917130470276
# Learned_CBS results!
# Cost: 1896, Gen_nodes: 13, Exp_nodes: 7, Total CT: 11.557246446609497
#
# ==============================================================
# Scene: test_69_80949
# CBS total CT: 7.953145980834961
#
# test_69_80949
# CBS result!
# Cost: 1454, Gen nodes: 165, Exp nodes: 83, total CT: 7.953145980834961
# ICBS result!
# Cost: 1454, Gen nodes: 54, Exp nodes: 30, total CT: 11.27710223197937
# Learned_CBS results!
# Cost: 1454, Gen_nodes: 3, Exp_nodes: 2, Total CT: 0.5591819286346436
#
# ==============================================================
# Scene: test_69_83208
# CBS total CT: 18.880091905593872
#
# test_69_83208
# CBS result!
# Cost: 1955, Gen nodes: 35, Exp nodes: 18, total CT: 18.880091905593872
# ICBS result!
# Cost: 1955, Gen nodes: 8, Exp nodes: 6, total CT: 10.415027379989624
# Learned_CBS results!
# Cost: 1955, Gen_nodes: 25, Exp_nodes: 13, Total CT: 16.957886934280396
#
# ==============================================================
# Scene: test_69_85518
# CBS total CT: 1.2914154529571533
#
# test_69_85518
# CBS result!
# Cost: 1571, Gen nodes: 23, Exp nodes: 12, total CT: 1.2914154529571533
# ICBS result!
# Cost: 1571, Gen nodes: 7, Exp nodes: 5, total CT: 2.0722646713256836
# Learned_CBS results!
# Cost: 1571, Gen_nodes: 17, Exp_nodes: 9, Total CT: 0.5580945014953613
#
# ==============================================================
# Scene: test_69_81587
# CBS total CT: 2.8840980529785156
#
# test_69_81587
# CBS result!
# Cost: 1794, Gen nodes: 63, Exp nodes: 32, total CT: 2.8840980529785156
# ICBS result!
# Cost: 1794, Gen nodes: 53, Exp nodes: 28, total CT: 20.220319509506226
# Learned_CBS results!
# Cost: 1794, Gen_nodes: 45, Exp_nodes: 23, Total CT: 9.545859098434448
#
# ==============================================================
# Scene: test_69_88341
# CBS total CT: 34.65656042098999
#
# test_69_88341
# CBS result!
# Cost: 1816, Gen nodes: 27, Exp nodes: 14, total CT: 34.65656042098999
# ICBS result!
# Cost: 1816, Gen nodes: 11, Exp nodes: 10, total CT: 142.4341425895691
# Learned_CBS results!
# Cost: 1816, Gen_nodes: 9, Exp_nodes: 5, Total CT: 18.320915460586548
#
# ==============================================================
# Scene: test_69_86904
# CBS total CT: 22.300849199295044
#
# test_69_86904
# CBS result!
# Cost: 1520, Gen nodes: 257, Exp nodes: 129, total CT: 22.300849199295044
# ICBS result!
# Cost: 1520, Gen nodes: 128, Exp nodes: 65, total CT: 32.22073841094971
# Learned_CBS results!
# Cost: 1520, Gen_nodes: 67, Exp_nodes: 34, Total CT: 3.4048314094543457
#
# ==============================================================
# Scene: test_69_82528
# CBS total CT: 4.402521848678589
#
# test_69_82528
# CBS result!
# Cost: 1732, Gen nodes: 37, Exp nodes: 19, total CT: 4.402521848678589
# ICBS result!
# Cost: 1732, Gen nodes: 16, Exp nodes: 12, total CT: 20.87793803215027
# Learned_CBS results!
# Cost: 1732, Gen_nodes: 19, Exp_nodes: 10, Total CT: 1.4525659084320068
#
# ==============================================================
# Scene: test_69_81839
# CBS total CT: 10.258067846298218
#
# test_69_81839
# CBS result!
# Cost: 1702, Gen nodes: 167, Exp nodes: 84, total CT: 10.258067846298218
# ICBS result!
# Cost: 1702, Gen nodes: 9, Exp nodes: 6, total CT: 3.871615171432495
# Learned_CBS results!
# Cost: 1702, Gen_nodes: 7, Exp_nodes: 4, Total CT: 0.7611429691314697
#
# ==============================================================
# Scene: test_69_83294
# CBS total CT: 10.549458503723145
#
# test_69_83294
# CBS result!
# Cost: 1660, Gen nodes: 49, Exp nodes: 25, total CT: 10.549458503723145
# ICBS result!
# Cost: 1660, Gen nodes: 29, Exp nodes: 18, total CT: 29.2868070602417
# Learned_CBS results!
# Cost: 1660, Gen_nodes: 3, Exp_nodes: 2, Total CT: 12.958607196807861
#
# ==============================================================
# Scene: test_69_82931
# CBS total CT: 13.430012226104736
#
# test_69_82931
# CBS result!
# Cost: 1645, Gen nodes: 33, Exp nodes: 17, total CT: 13.430012226104736
# ICBS result!
# Cost: 1645, Gen nodes: 8, Exp nodes: 6, total CT: 9.103193044662476
# Learned_CBS results!
# Cost: 1645, Gen_nodes: 5, Exp_nodes: 3, Total CT: 2.2105588912963867
#
# ==============================================================
# Scene: test_69_89651
# CBS total CT: 6.242251634597778
#
# test_69_89651
# CBS result!
# Cost: 1516, Gen nodes: 39, Exp nodes: 20, total CT: 6.242251634597778
# ICBS result!
# Cost: 1516, Gen nodes: 29, Exp nodes: 19, total CT: 20.654399156570435
# Learned_CBS results!
# Cost: 1516, Gen_nodes: 43, Exp_nodes: 22, Total CT: 2.1493642330169678
#
# ==============================================================
# Scene: test_69_82172
# CBS total CT: 58.57638454437256
#
# test_69_82172
# CBS result!
# Cost: 1701, Gen nodes: 879, Exp nodes: 440, total CT: 58.57638454437256
# ICBS result!
# Cost: 1701, Gen nodes: 876, Exp nodes: 440, total CT: 317.60997915267944
# Learned_CBS results!
# Cost: 1701, Gen_nodes: 37, Exp_nodes: 19, Total CT: 3.0858099460601807
#
# ==============================================================
# Scene: test_69_87454
# CBS total CT: 34.98011255264282
#
# test_69_87454
# CBS result!
# Cost: 1575, Gen nodes: 943, Exp nodes: 472, total CT: 34.98011255264282
# ICBS result!
# Cost: 1575, Gen nodes: 133, Exp nodes: 68, total CT: 17.30887007713318
# Learned_CBS results!
# Cost: 1575, Gen_nodes: 939, Exp_nodes: 470, Total CT: 15.257489919662476
#
# ==============================================================
# Scene: test_69_89128
# CBS total CT: 3.5541481971740723
#
# test_69_89128
# CBS result!
# Cost: 1638, Gen nodes: 23, Exp nodes: 12, total CT: 3.5541481971740723
# ICBS result!
# Cost: 1638, Gen nodes: 19, Exp nodes: 12, total CT: 13.241278648376465
# Learned_CBS results!
# Cost: 1638, Gen_nodes: 1, Exp_nodes: 1, Total CT: 0.668978214263916
#
# ==============================================================
# Scene: test_69_82187
# CBS total CT: 5.224957227706909
#
# test_69_82187
# CBS result!
# Cost: 1856, Gen nodes: 41, Exp nodes: 21, total CT: 5.224957227706909
# ICBS result!
# Cost: 1856, Gen nodes: 15, Exp nodes: 9, total CT: 5.239004373550415
# Learned_CBS results!
# Cost: 1856, Gen_nodes: 9, Exp_nodes: 5, Total CT: 5.678491592407227
#
# ==============================================================
# Scene: test_69_82445
# CBS total CT: 7.294370412826538
#
# test_69_82445
# CBS result!
# Cost: 1856, Gen nodes: 97, Exp nodes: 49, total CT: 7.294370412826538
# ICBS result!
# Cost: 1856, Gen nodes: 12, Exp nodes: 9, total CT: 10.834820747375488
# Learned_CBS results!
# Cost: 1856, Gen_nodes: 445, Exp_nodes: 223, Total CT: 12.746779203414917
#
# ==============================================================
# Scene: test_69_89880
# CBS total CT: 8.911805391311646
#
# test_69_89880
# CBS result!
# Cost: 1850, Gen nodes: 21, Exp nodes: 11, total CT: 8.911805391311646
# ICBS result!
# Cost: 1850, Gen nodes: 12, Exp nodes: 10, total CT: 24.34738826751709
# Learned_CBS results!
# Cost: 1850, Gen_nodes: 5, Exp_nodes: 3, Total CT: 0.8872077465057373
#
# ==============================================================
# Scene: test_69_85816
# CBS total CT: 10.896644830703735
#
# test_69_85816
# CBS result!
# Cost: 2061, Gen nodes: 51, Exp nodes: 26, total CT: 10.896644830703735
# ICBS result!
# Cost: 2061, Gen nodes: 16, Exp nodes: 10, total CT: 27.586575746536255
# Learned_CBS results!
# Cost: 2061, Gen_nodes: 9, Exp_nodes: 5, Total CT: 1.2873742580413818
#
# ==============================================================
# Scene: test_69_86459
# CBS total CT: 3.61313796043396
#
# ==============================================================
# Scene: test_69_87928
# CBS total CT: 45.42735052108765
#
# test_69_87928
# CBS result!
# Cost: 1794, Gen nodes: 521, Exp nodes: 261, total CT: 45.42735052108765
# ICBS result!
# Cost: 1794, Gen nodes: 516, Exp nodes: 261, total CT: 462.98834109306335
# Learned_CBS results!
# Cost: 1794, Gen_nodes: 17, Exp_nodes: 9, Total CT: 1.1025218963623047
#
# ==============================================================
# Scene: test_69_86573
# CBS total CT: 26.522468090057373
#
# test_69_86573
# CBS result!
# Cost: 1909, Gen nodes: 39, Exp nodes: 20, total CT: 26.522468090057373
# ICBS result!
# Cost: 1909, Gen nodes: 19, Exp nodes: 14, total CT: 166.3344600200653
# Learned_CBS results!
# Cost: 1909, Gen_nodes: 11, Exp_nodes: 6, Total CT: 1.1500511169433594
#
# ==============================================================
# Scene: test_69_89940
# CBS total CT: 23.542994737625122
#
# test_69_89940
# CBS result!
# Cost: 1543, Gen nodes: 27, Exp nodes: 14, total CT: 23.542994737625122
# ICBS result!
# Cost: 1543, Gen nodes: 9, Exp nodes: 7, total CT: 67.49173307418823
# Learned_CBS results!
# Cost: 1543, Gen_nodes: 9, Exp_nodes: 5, Total CT: 1.0890898704528809
#
# ==============================================================
# Scene: test_69_86981
# CBS total CT: 4.802062749862671
#
# test_69_86981
# CBS result!
# Cost: 1759, Gen nodes: 59, Exp nodes: 30, total CT: 4.802062749862671
# ICBS result!
# Cost: 1759, Gen nodes: 30, Exp nodes: 17, total CT: 16.461388111114502
# Learned_CBS results!
# Cost: 1759, Gen_nodes: 21, Exp_nodes: 11, Total CT: 0.9905173778533936
#
# ==============================================================
# Scene: test_69_89759
# CBS total CT: 3.3675477504730225
#
# test_69_89759
# CBS result!
# Cost: 1742, Gen nodes: 19, Exp nodes: 10, total CT: 3.3675477504730225
# ICBS result!
# Cost: 1742, Gen nodes: 11, Exp nodes: 9, total CT: 12.060539960861206
# Learned_CBS results!
# Cost: 1742, Gen_nodes: 7, Exp_nodes: 4, Total CT: 2.346792459487915
#
# ==============================================================
# Scene: test_69_83618
# CBS total CT: 9.997008323669434
#
# test_69_83618
# CBS result!
# Cost: 1807, Gen nodes: 23, Exp nodes: 12, total CT: 9.997008323669434
# ICBS result!
# Cost: 1807, Gen nodes: 18, Exp nodes: 12, total CT: 33.87729549407959
# Learned_CBS results!
# Cost: 1807, Gen_nodes: 17, Exp_nodes: 9, Total CT: 1.2923328876495361
#
# ==============================================================
# Scene: test_69_81649
# CBS total CT: 9.114210605621338
#
# test_69_81649
# CBS result!
# Cost: 1562, Gen nodes: 51, Exp nodes: 26, total CT: 9.114210605621338
# ICBS result!
# Cost: 1562, Gen nodes: 16, Exp nodes: 10, total CT: 54.38596224784851
# Learned_CBS results!
# Cost: 1562, Gen_nodes: 3, Exp_nodes: 2, Total CT: 0.6174280643463135
#
# ==============================================================
# Scene: test_69_83112
# CBS total CT: 23.298625946044922
#
# test_69_83112
# CBS result!
# Cost: 1967, Gen nodes: 287, Exp nodes: 144, total CT: 23.298625946044922
# ICBS result!
# Cost: 1967, Gen nodes: 67, Exp nodes: 35, total CT: 19.488411903381348
# Learned_CBS results!
# Cost: 1967, Gen_nodes: 9, Exp_nodes: 5, Total CT: 13.133733034133911
#
# ==============================================================
# Scene: test_69_87680
# CBS total CT: 6.0969765186309814
#
# test_69_87680
# CBS result!
# Cost: 1596, Gen nodes: 51, Exp nodes: 26, total CT: 6.0969765186309814
# ICBS result!
# Cost: 1596, Gen nodes: 17, Exp nodes: 11, total CT: 16.78024125099182
# Learned_CBS results!
# Cost: 1596, Gen_nodes: 25, Exp_nodes: 13, Total CT: 1.5332894325256348
#
# ==============================================================
# Scene: test_69_82691
# CBS total CT: 16.694448709487915
#
# test_69_82691
# CBS result!
# Cost: 1421, Gen nodes: 107, Exp nodes: 54, total CT: 16.694448709487915
# ICBS result!
# Cost: 1421, Gen nodes: 9, Exp nodes: 7, total CT: 4.114726543426514
# Learned_CBS results!
# Cost: 1421, Gen_nodes: 13, Exp_nodes: 7, Total CT: 2.0595128536224365
#
# ==============================================================
# Scene: test_69_84710
# CBS total CT: 56.44667100906372
#
# test_69_84710
# CBS result!
# Cost: 1612, Gen nodes: 21, Exp nodes: 11, total CT: 56.44667100906372
# ICBS result!
# Cost: 1612, Gen nodes: 12, Exp nodes: 10, total CT: 202.0743899345398
# Learned_CBS results!
# Cost: 1612, Gen_nodes: 5, Exp_nodes: 3, Total CT: 11.061208486557007
#
# ==============================================================
# Scene: test_69_83049
# CBS total CT: 73.39116311073303
#
# test_69_83049
# CBS result!
# Cost: 1590, Gen nodes: 1443, Exp nodes: 722, total CT: 73.39116311073303
# ICBS result!
# Cost: 1590, Gen nodes: 132, Exp nodes: 68, total CT: 19.819766759872437
# Learned_CBS results!
# Cost: 1590, Gen_nodes: 5, Exp_nodes: 3, Total CT: 0.48343372344970703
#
# ==============================================================
# Scene: test_69_84028
# CBS total CT: 65.7744448184967
#
# test_69_84028
# CBS result!
# Cost: 1621, Gen nodes: 47, Exp nodes: 24, total CT: 65.7744448184967
# ICBS result!
# Cost: 1621, Gen nodes: 8, Exp nodes: 6, total CT: 11.67452597618103
# Learned_CBS results!
# Cost: 1621, Gen_nodes: 15, Exp_nodes: 8, Total CT: 6.227257013320923
#
# ==============================================================
# Scene: test_69_85491
# CBS total CT: 18.928247928619385
#
# test_69_85491
# CBS result!
# Cost: 1747, Gen nodes: 263, Exp nodes: 132, total CT: 18.928247928619385
# ICBS result!
# Cost: 1747, Gen nodes: 85, Exp nodes: 45, total CT: 55.47224497795105
# Learned_CBS results!
# Cost: 1747, Gen_nodes: 61, Exp_nodes: 31, Total CT: 6.537651062011719
#
# ==============================================================
# Scene: test_69_89700
# CBS total CT: 2.903128147125244
#
# test_69_89700
# CBS result!
# Cost: 1935, Gen nodes: 31, Exp nodes: 16, total CT: 2.903128147125244
# ICBS result!
# Cost: 1935, Gen nodes: 9, Exp nodes: 6, total CT: 4.608578443527222
# Learned_CBS results!
# Cost: 1935, Gen_nodes: 11, Exp_nodes: 6, Total CT: 13.258014678955078
#
# ==============================================================
# Scene: test_69_84407
# CBS total CT: 132.7648103237152
#
# test_69_84407
# CBS result!
# Cost: 1820, Gen nodes: 2167, Exp nodes: 1084, total CT: 132.7648103237152
# ICBS result!
# Cost: 1820, Gen nodes: 66, Exp nodes: 35, total CT: 4.37812614440918
# Learned_CBS results!
# Cost: 1820, Gen_nodes: 197, Exp_nodes: 99, Total CT: 14.147425889968872
#
# ==============================================================
# Scene: test_69_87730
# CBS total CT: 80.42866611480713
#
# test_69_87730
# CBS result!
# Cost: 1870, Gen nodes: 455, Exp nodes: 228, total CT: 80.42866611480713
# ICBS result!
# Cost: 1870, Gen nodes: 18, Exp nodes: 11, total CT: 59.1324143409729
# Learned_CBS results!
# Cost: 1870, Gen_nodes: 7, Exp_nodes: 4, Total CT: 2.7299857139587402
#
# ==============================================================
# Scene: test_69_84111
# CBS total CT: 2.7084269523620605
#
# test_69_84111
# CBS result!
# Cost: 1643, Gen nodes: 23, Exp nodes: 12, total CT: 2.7084269523620605
# ICBS result!
# Cost: 1643, Gen nodes: 15, Exp nodes: 9, total CT: 3.70926570892334
# Learned_CBS results!
# Cost: 1643, Gen_nodes: 3, Exp_nodes: 2, Total CT: 0.6288249492645264
#
# ==============================================================
# Scene: test_69_87056
# CBS total CT: 51.78652501106262
#
# test_69_87056
# CBS result!
# Cost: 1553, Gen nodes: 73, Exp nodes: 37, total CT: 51.78652501106262
# ICBS result!
# Cost: 1553, Gen nodes: 8, Exp nodes: 6, total CT: 12.936583280563354
# Learned_CBS results!
# Cost: 1553, Gen_nodes: 9, Exp_nodes: 5, Total CT: 3.0434494018554688
#
# ==============================================================
# Scene: test_69_85620
# CBS total CT: 2.507453680038452
#
# test_69_85620
# CBS result!
# Cost: 1934, Gen nodes: 19, Exp nodes: 10, total CT: 2.507453680038452
# ICBS result!
# Cost: 1934, Gen nodes: 16, Exp nodes: 10, total CT: 4.495521545410156
# Learned_CBS results!
# Cost: 1934, Gen_nodes: 3, Exp_nodes: 2, Total CT: 0.9676799774169922
#
# ==============================================================
# Scene: test_69_82386
# CBS total CT: 2.5969078540802
#
# test_69_82386
# CBS result!
# Cost: 1505, Gen nodes: 57, Exp nodes: 29, total CT: 2.5969078540802
# ICBS result!
# Cost: 1505, Gen nodes: 14, Exp nodes: 8, total CT: 2.010721445083618
# Learned_CBS results!
# Cost: 1505, Gen_nodes: 43, Exp_nodes: 22, Total CT: 1.127678632736206
#
# ==============================================================
# Scene: test_69_87352
# CBS total CT: 18.007238626480103
#
# test_69_87352
# CBS result!
# Cost: 1704, Gen nodes: 281, Exp nodes: 141, total CT: 18.007238626480103
# ICBS result!
# Cost: 1704, Gen nodes: 57, Exp nodes: 30, total CT: 21.66645836830139
# Learned_CBS results!
# Cost: 1704, Gen_nodes: 99, Exp_nodes: 50, Total CT: 11.714386701583862
#
# ==============================================================
# Scene: test_69_81699
# CBS total CT: 52.02413558959961
#
# test_69_81699
# CBS result!
# Cost: 1730, Gen nodes: 147, Exp nodes: 74, total CT: 52.02413558959961
# ICBS result!
# Cost: 1730, Gen nodes: 11, Exp nodes: 9, total CT: 46.34844923019409
# Learned_CBS results!
# Cost: 1730, Gen_nodes: 11, Exp_nodes: 6, Total CT: 3.0948710441589355
#
# ==============================================================
# Scene: test_69_85785
# CBS total CT: 2.476588010787964
#
# test_69_85785
# CBS result!
# Cost: 1475, Gen nodes: 29, Exp nodes: 15, total CT: 2.476588010787964
# ICBS result!
# Cost: 1475, Gen nodes: 15, Exp nodes: 9, total CT: 6.348790168762207
# Learned_CBS results!
# Cost: 1475, Gen_nodes: 31, Exp_nodes: 16, Total CT: 9.676397323608398
#
# ==============================================================
# Scene: test_69_83074
# CBS total CT: 10.734266996383667
#
# test_69_83074
# CBS result!
# Cost: 1530, Gen nodes: 279, Exp nodes: 140, total CT: 10.734266996383667
# ICBS result!
# Cost: 1530, Gen nodes: 9, Exp nodes: 6, total CT: 1.7319371700286865
# Learned_CBS results!
# Cost: 1530, Gen_nodes: 43, Exp_nodes: 22, Total CT: 4.695388078689575
#
# ==============================================================
# Scene: test_69_89521
# CBS total CT: 7.211609125137329
#
# test_69_89521
# CBS result!
# Cost: 1909, Gen nodes: 31, Exp nodes: 16, total CT: 7.211609125137329
# ICBS result!
# Cost: 1909, Gen nodes: 19, Exp nodes: 13, total CT: 20.210620164871216
# Learned_CBS results!
# Cost: 1909, Gen_nodes: 5, Exp_nodes: 3, Total CT: 1.1247570514678955
#
# ==============================================================
# Scene: test_69_88422
# CBS total CT: 161.67425322532654
#
# test_69_88422
# CBS result!
# Cost: 1619, Gen nodes: 77, Exp nodes: 39, total CT: 161.67425322532654
# ICBS result!
# Cost: 1619, Gen nodes: 10, Exp nodes: 8, total CT: 48.58931517601013
# Learned_CBS results!
# Cost: 1619, Gen_nodes: 9, Exp_nodes: 5, Total CT: 1.4606621265411377
#
# ==============================================================
# Scene: test_69_83487
# CBS total CT: 52.2934045791626
#
# test_69_83487
# CBS result!
# Cost: 1729, Gen nodes: 1571, Exp nodes: 786, total CT: 52.2934045791626
# ICBS result!
# Cost: 1729, Gen nodes: 17, Exp nodes: 11, total CT: 18.79507803916931
# Learned_CBS results!
# Cost: 1729, Gen_nodes: 361, Exp_nodes: 181, Total CT: 7.6155829429626465
#
# ==============================================================
# Scene: test_69_83163
# CBS total CT: 29.829307556152344
#
# test_69_83163
# CBS result!
# Cost: 1750, Gen nodes: 39, Exp nodes: 20, total CT: 29.829307556152344
# ICBS result!
# Cost: 1750, Gen nodes: 19, Exp nodes: 12, total CT: 86.74447321891785
# Learned_CBS results!
# Cost: 1750, Gen_nodes: 13, Exp_nodes: 7, Total CT: 4.285912752151489
#
# ==============================================================
# Scene: test_69_81086
# CBS total CT: 26.206052541732788
#
# test_69_81086
# CBS result!
# Cost: 1569, Gen nodes: 299, Exp nodes: 150, total CT: 26.206052541732788
# ICBS result!
# Cost: 1569, Gen nodes: 31, Exp nodes: 18, total CT: 25.37585997581482
# Learned_CBS results!
# Cost: 1569, Gen_nodes: 9, Exp_nodes: 5, Total CT: 0.8036203384399414
#
# ==============================================================
# Scene: test_69_82697
# CBS total CT: 31.07061004638672
#
# test_69_82697
# CBS result!
# Cost: 1687, Gen nodes: 387, Exp nodes: 194, total CT: 31.07061004638672
# ICBS result!
# Cost: 1687, Gen nodes: 131, Exp nodes: 68, total CT: 40.71586465835571
# Learned_CBS results!
# Cost: 1687, Gen_nodes: 2055, Exp_nodes: 1028, Total CT: 159.22139143943787
#
# ==============================================================
# Scene: test_69_81805
# CBS total CT: 9.024893045425415
#
# test_69_81805
# CBS result!
# Cost: 1851, Gen nodes: 27, Exp nodes: 14, total CT: 9.024893045425415
# ICBS result!
# Cost: 1851, Gen nodes: 9, Exp nodes: 7, total CT: 14.327394962310791
# Learned_CBS results!
# Cost: 1851, Gen_nodes: 11, Exp_nodes: 6, Total CT: 6.893018484115601
#
# ==============================================================
# Scene: test_69_88619
# CBS total CT: 28.51380968093872
#
# test_69_88619
# CBS result!
# Cost: 2025, Gen nodes: 57, Exp nodes: 29, total CT: 28.51380968093872
# ICBS result!
# Cost: 2025, Gen nodes: 10, Exp nodes: 8, total CT: 27.417439222335815
# Learned_CBS results!
# Cost: 2025, Gen_nodes: 7, Exp_nodes: 4, Total CT: 6.738635778427124
#
# ==============================================================
# Scene: test_69_87021
# CBS total CT: 9.557745456695557
#
# test_69_87021
# CBS result!
# Cost: 1717, Gen nodes: 19, Exp nodes: 10, total CT: 9.557745456695557
# ICBS result!
# Cost: 1717, Gen nodes: 9, Exp nodes: 7, total CT: 14.7773118019104
# Learned_CBS results!
# Cost: 1717, Gen_nodes: 11, Exp_nodes: 6, Total CT: 3.905130386352539
#
# ==============================================================
# Scene: test_69_81467
# CBS total CT: 164.89688181877136
#
# test_69_81467
# CBS result!
# Cost: 1874, Gen nodes: 1031, Exp nodes: 516, total CT: 164.89688181877136
# ICBS result!
# Cost: 1874, Gen nodes: 38, Exp nodes: 21, total CT: 31.88622546195984
# Learned_CBS results!
# Cost: 1874, Gen_nodes: 11, Exp_nodes: 6, Total CT: 9.979470014572144
#
# ==============================================================
# Scene: test_69_83876
# CBS total CT: 13.296298265457153
#
# test_69_83876
# CBS result!
# Cost: 1586, Gen nodes: 629, Exp nodes: 315, total CT: 13.296298265457153
# ICBS result!
# Cost: 1586, Gen nodes: 15, Exp nodes: 9, total CT: 4.215570449829102
# Learned_CBS results!
# Cost: 1586, Gen_nodes: 59, Exp_nodes: 30, Total CT: 1.0134098529815674
#
# ==============================================================
# Scene: test_69_81430
# CBS total CT: 4.925386190414429
#
# test_69_81430
# CBS result!
# Cost: 1602, Gen nodes: 19, Exp nodes: 10, total CT: 4.925386190414429
# ICBS result!
# Cost: 1602, Gen nodes: 12, Exp nodes: 10, total CT: 21.304813623428345
# Learned_CBS results!
# Cost: 1602, Gen_nodes: 3, Exp_nodes: 2, Total CT: 4.922234773635864
#
# ==============================================================
# Scene: test_69_88355
# CBS total CT: 14.825451612472534
#
# test_69_88355
# CBS result!
# Cost: 1692, Gen nodes: 41, Exp nodes: 21, total CT: 14.825451612472534
# ICBS result!
# Cost: 1692, Gen nodes: 28, Exp nodes: 17, total CT: 21.94596219062805
# Learned_CBS results!
# Cost: 1692, Gen_nodes: 19, Exp_nodes: 10, Total CT: 17.763978958129883
#
# ==============================================================
# Scene: test_69_84482
# CBS total CT: 3.3221592903137207
#
# test_69_84482
# CBS result!
# Cost: 1597, Gen nodes: 21, Exp nodes: 11, total CT: 3.3221592903137207
# ICBS result!
# Cost: 1597, Gen nodes: 12, Exp nodes: 8, total CT: 3.6394946575164795
# Learned_CBS results!
# Cost: 1597, Gen_nodes: 9, Exp_nodes: 5, Total CT: 3.9779114723205566
#
# ==============================================================
# Scene: test_69_85212
# CBS total CT: 141.97534918785095
#
# test_69_85212
# CBS result!
# Cost: 1442, Gen nodes: 2057, Exp nodes: 1029, total CT: 141.97534918785095
# ICBS result!
# Cost: 1442, Gen nodes: 1029, Exp nodes: 517, total CT: 354.621506690979
# Learned_CBS results!
# Cost: 1442, Gen_nodes: 17, Exp_nodes: 9, Total CT: 0.8848986625671387
#
# ==============================================================
# Scene: test_69_81315
# CBS total CT: 98.83952307701111
#
# test_69_81315
# CBS result!
# Cost: 1800, Gen nodes: 1743, Exp nodes: 872, total CT: 98.83952307701111
# ICBS result!
# Cost: 1800, Gen nodes: 18, Exp nodes: 12, total CT: 31.166101932525635
# Learned_CBS results!
# Cost: 1800, Gen_nodes: 263, Exp_nodes: 132, Total CT: 5.645336151123047
#
# ==============================================================
# Scene: test_69_83322
# CBS total CT: 16.034860610961914
#
# test_69_83322
# CBS result!
# Cost: 1648, Gen nodes: 267, Exp nodes: 134, total CT: 16.034860610961914
# ICBS result!
# Cost: 1648, Gen nodes: 59, Exp nodes: 31, total CT: 4.4614410400390625
# Learned_CBS results!
# Cost: 1648, Gen_nodes: 51, Exp_nodes: 26, Total CT: 17.35015106201172
#
# ==============================================================
# Scene: test_69_89312
# CBS total CT: 19.309664726257324
#
# test_69_89312
# CBS result!
# Cost: 1498, Gen nodes: 27, Exp nodes: 14, total CT: 19.309664726257324
# ICBS result!
# Cost: 1498, Gen nodes: 22, Exp nodes: 14, total CT: 44.52954363822937
# Learned_CBS results!
# Cost: 1498, Gen_nodes: 7, Exp_nodes: 4, Total CT: 14.81004548072815
#
# ==============================================================
# Scene: test_69_80360
# CBS total CT: 5.717592239379883
#
# test_69_80360
# CBS result!
# Cost: 1641, Gen nodes: 19, Exp nodes: 10, total CT: 5.717592239379883
# ICBS result!
# Cost: 1641, Gen nodes: 10, Exp nodes: 10, total CT: 15.834012031555176
# Learned_CBS results!
# Cost: 1641, Gen_nodes: 7, Exp_nodes: 4, Total CT: 14.121507406234741
#
# ==============================================================
# Scene: test_69_83212
# CBS total CT: 1.6419377326965332
#
# test_69_83212
# CBS result!
# Cost: 1591, Gen nodes: 19, Exp nodes: 10, total CT: 1.6419377326965332
# ICBS result!
# Cost: 1591, Gen nodes: 16, Exp nodes: 10, total CT: 4.8001978397369385
# Learned_CBS results!
# Cost: 1591, Gen_nodes: 17, Exp_nodes: 9, Total CT: 0.632796049118042
#
# ==============================================================
# Scene: test_69_86969
# CBS total CT: 26.44068217277527
#
# test_69_86969
# CBS result!
# Cost: 1775, Gen nodes: 131, Exp nodes: 66, total CT: 26.44068217277527
# ICBS result!
# Cost: 1775, Gen nodes: 128, Exp nodes: 66, total CT: 96.91054320335388
# Learned_CBS results!
# Cost: 1775, Gen_nodes: 5, Exp_nodes: 3, Total CT: 8.89453911781311
#
# ==============================================================
# Scene: test_69_88014
# CBS total CT: 13.66365671157837
#
# test_69_88014
# CBS result!
# Cost: 2009, Gen nodes: 19, Exp nodes: 10, total CT: 13.66365671157837
# ICBS result!
# Cost: 2009, Gen nodes: 10, Exp nodes: 9, total CT: 63.98007869720459
# Learned_CBS results!
# Cost: 2009, Gen_nodes: 3, Exp_nodes: 2, Total CT: 3.2724318504333496
#
# ==============================================================
# Scene: test_69_82424
# CBS total CT: 57.24727201461792
#
# test_69_82424
# CBS result!
# Cost: 1621, Gen nodes: 263, Exp nodes: 132, total CT: 57.24727201461792
# ICBS result!
# Cost: 1621, Gen nodes: 258, Exp nodes: 132, total CT: 225.3220567703247
# Learned_CBS results!
# Cost: 1621, Gen_nodes: 1, Exp_nodes: 1, Total CT: 0.5239853858947754
#
# ==============================================================
# Scene: test_69_89087
# CBS total CT: 5.335195064544678
#
# test_69_89087
# CBS result!
# Cost: 1719, Gen nodes: 23, Exp nodes: 12, total CT: 5.335195064544678
# ICBS result!
# Cost: 1719, Gen nodes: 14, Exp nodes: 9, total CT: 9.1635582447052
# Learned_CBS results!
# Cost: 1719, Gen_nodes: 5, Exp_nodes: 3, Total CT: 3.823009967803955
#
# ==============================================================
# Scene: test_69_83366
# CBS total CT: 8.486401557922363
#
# test_69_83366
# CBS result!
# Cost: 1768, Gen nodes: 73, Exp nodes: 37, total CT: 8.486401557922363
# ICBS result!
# Cost: 1768, Gen nodes: 67, Exp nodes: 36, total CT: 25.207696676254272
# Learned_CBS results!
# ...
#
# test_69_81017
# CBS result!
# Cost: 1968, Gen nodes: 31, Exp nodes: 16, total CT: 6.037981271743774
# ICBS result!
# Cost: 1968, Gen nodes: 16, Exp nodes: 10, total CT: 15.470315217971802
# Learned_CBS results!
# Cost: 1968, Gen_nodes: 3, Exp_nodes: 2, Total CT: 1.2747550010681152
#
# ==============================================================
# Scene: test_69_81284
# CBS total CT: 56.931381940841675
#
# test_69_81284
# CBS result!
# Cost: 1431, Gen nodes: 515, Exp nodes: 258, total CT: 56.931381940841675
# ICBS result!
# Cost: 1431, Gen nodes: 129, Exp nodes: 66, total CT: 35.67359948158264
# Learned_CBS results!
# Cost: 1431, Gen_nodes: 7, Exp_nodes: 4, Total CT: 0.8727982044219971
#
# ==============================================================
# Scene: test_69_80605
# CBS total CT: 26.183310747146606
#
# test_69_80605
# CBS result!
# Cost: 1944, Gen nodes: 105, Exp nodes: 53, total CT: 26.183310747146606
# ICBS result!
# Cost: 1944, Gen nodes: 23, Exp nodes: 15, total CT: 88.12421488761902
# Learned_CBS results!
# Cost: 1944, Gen_nodes: 7, Exp_nodes: 4, Total CT: 1.6224255561828613
#
# ==============================================================
# Scene: test_69_86995
# CBS total CT: 3.5867512226104736
#
# test_69_86995
# CBS result!
# Cost: 1445, Gen nodes: 51, Exp nodes: 26, total CT: 3.5867512226104736
# ICBS result!
# Cost: 1445, Gen nodes: 15, Exp nodes: 9, total CT: 4.092175483703613
# Learned_CBS results!
# Cost: 1445, Gen_nodes: 33, Exp_nodes: 17, Total CT: 1.4802601337432861
#
# ==============================================================
# Scene: test_69_83295
# CBS total CT: 14.644840240478516
#
# test_69_83295
# CBS result!
# Cost: 1835, Gen nodes: 123, Exp nodes: 62, total CT: 14.644840240478516
# ICBS result!
# Cost: 1835, Gen nodes: 117, Exp nodes: 62, total CT: 54.17577815055847
# Learned_CBS results!
# Cost: 1835, Gen_nodes: 7, Exp_nodes: 4, Total CT: 8.282607555389404
#
# ==============================================================
# Scene: test_69_88877
# CBS total CT: 163.1700804233551
#
# test_69_88877
# CBS result!
# Cost: 1974, Gen nodes: 1113, Exp nodes: 557, total CT: 163.1700804233551
# ICBS result!
# Cost: 1974, Gen nodes: 628, Exp nodes: 319, total CT: 677.8192341327667
# Learned_CBS results!
# Cost: 1974, Gen_nodes: 5, Exp_nodes: 3, Total CT: 1.0788605213165283
#
# ==============================================================
# Scene: test_69_84378
# CBS total CT: 213.86865186691284
#
# test_69_84378
# CBS result!
# Cost: 1723, Gen nodes: 8165, Exp nodes: 4083, total CT: 213.86865186691284
# ICBS result!
# Cost: 1723, Gen nodes: 128, Exp nodes: 65, total CT: 12.546191215515137
# Learned_CBS results!
# Cost: 1723, Gen_nodes: 5, Exp_nodes: 3, Total CT: 0.6566891670227051
#
# ==============================================================
# Scene: test_69_89001
# CBS total CT: 3.7699480056762695
#
# test_69_89001
# CBS result!
# Cost: 1587, Gen nodes: 21, Exp nodes: 11, total CT: 3.7699480056762695
# ICBS result!
# Cost: 1587, Gen nodes: 8, Exp nodes: 7, total CT: 9.192998886108398
# Learned_CBS results!
# Cost: 1587, Gen_nodes: 3, Exp_nodes: 2, Total CT: 0.5453014373779297
#
# ==============================================================
# Scene: test_69_87388
# CBS total CT: 113.81905126571655
#
# test_69_87388
# CBS result!
# Cost: 1691, Gen nodes: 31, Exp nodes: 16, total CT: 113.81905126571655
# ICBS result!
# Cost: 1691, Gen nodes: 8, Exp nodes: 6, total CT: 108.00974297523499
# Learned_CBS results!
# Cost: 1691, Gen_nodes: 21, Exp_nodes: 11, Total CT: 11.955671548843384
#
# ==============================================================
# Scene: test_69_85657
# CBS total CT: 52.722841024398804
#
# test_69_85657
# CBS result!
# Cost: 1384, Gen nodes: 179, Exp nodes: 90, total CT: 52.722841024398804
# ICBS result!
# Cost: 1384, Gen nodes: 115, Exp nodes: 60, total CT: 154.30549025535583
# Learned_CBS results!
# Cost: 1384, Gen_nodes: 49, Exp_nodes: 25, Total CT: 3.1187937259674072
#
# ==============================================================
# Scene: test_69_82171
# CBS total CT: 101.53436064720154
#
# test_69_82171
# CBS result!
# Cost: 1691, Gen nodes: 515, Exp nodes: 258, total CT: 101.53436064720154
# ICBS result!
# Cost: 1691, Gen nodes: 130, Exp nodes: 67, total CT: 107.38885283470154
# Learned_CBS results!
# Cost: 1691, Gen_nodes: 7, Exp_nodes: 4, Total CT: 1.586756706237793
#
# ==============================================================
# Scene: test_69_88899
# CBS total CT: 36.36473488807678
#
# test_69_88899
# CBS result!
# Cost: 1682, Gen nodes: 69, Exp nodes: 35, total CT: 36.36473488807678
# ICBS result!
# Cost: 1682, Gen nodes: 65, Exp nodes: 35, total CT: 287.87347435951233
# Learned_CBS results!
# Cost: 1682, Gen_nodes: 3, Exp_nodes: 2, Total CT: 2.2816483974456787
#
# ==============================================================
# Scene: test_69_85255
# CBS total CT: 8.363648176193237
#
# test_69_85255
# CBS result!
# Cost: 1614, Gen nodes: 131, Exp nodes: 66, total CT: 8.363648176193237
# ICBS result!
# Cost: 1614, Gen nodes: 128, Exp nodes: 66, total CT: 37.97375774383545
# Learned_CBS results!
# Cost: 1614, Gen_nodes: 127, Exp_nodes: 64, Total CT: 3.4882235527038574
#
# ==============================================================
# Scene: test_69_89422
# CBS total CT: 22.59817385673523
#
# test_69_89422
# CBS result!
# Cost: 1672, Gen nodes: 23, Exp nodes: 12, total CT: 22.59817385673523
# ICBS result!
# Cost: 1672, Gen nodes: 7, Exp nodes: 5, total CT: 5.183707237243652
# Learned_CBS results!
# Cost: 1672, Gen_nodes: 17, Exp_nodes: 9, Total CT: 3.760962724685669
#
# ==============================================================
# Scene: test_69_82876
# CBS total CT: 3.78668212890625
#
# test_69_82876
# CBS result!
# Cost: 1906, Gen nodes: 19, Exp nodes: 10, total CT: 3.78668212890625
# ICBS result!
# Cost: 1906, Gen nodes: 10, Exp nodes: 8, total CT: 10.69408655166626
# Learned_CBS results!
# Cost: 1906, Gen_nodes: 9, Exp_nodes: 5, Total CT: 1.5070040225982666
#
# ==============================================================
# Scene: test_69_81695
# CBS total CT: 10.855989217758179
#
# ==============================================================
# Scene: test_69_86178
# CBS total CT: 26.710721492767334
#
# test_69_86178
# CBS result!
# Cost: 1915, Gen nodes: 193, Exp nodes: 97, total CT: 26.710721492767334
# ICBS result!
# Cost: 1915, Gen nodes: 128, Exp nodes: 66, total CT: 48.035181522369385
# Learned_CBS results!
# Cost: 1915, Gen_nodes: 11, Exp_nodes: 6, Total CT: 1.0452313423156738
#
# ==============================================================
# Scene: test_69_88556
# CBS total CT: 244.93519115447998
#
# test_69_88556
# CBS result!
# Cost: 1854, Gen nodes: 4103, Exp nodes: 2052, total CT: 244.93519115447998
# ICBS result!
# Cost: 1854, Gen nodes: 4099, Exp nodes: 2052, total CT: 2426.2013823986053
# Learned_CBS results!
# Cost: 1854, Gen_nodes: 7, Exp_nodes: 4, Total CT: 2.098761796951294
#
# ==============================================================
# Scene: test_69_87897
# CBS total CT: 2.1135480403900146
#
# test_69_87897
# CBS result!
# Cost: 1622, Gen nodes: 27, Exp nodes: 14, total CT: 2.1135480403900146
# ICBS result!
# Cost: 1622, Gen nodes: 25, Exp nodes: 14, total CT: 6.696467876434326
# Learned_CBS results!
# Cost: 1622, Gen_nodes: 3, Exp_nodes: 2, Total CT: 2.8099114894866943
#
# ==============================================================
# Scene: test_69_83790
# CBS total CT: 3.6588239669799805
#
# test_69_83790
# CBS result!
# Cost: 1803, Gen nodes: 55, Exp nodes: 28, total CT: 3.6588239669799805
# ICBS result!
# Cost: 1803, Gen nodes: 7, Exp nodes: 5, total CT: 2.884963035583496
# Learned_CBS results!
# Cost: 1803, Gen_nodes: 5, Exp_nodes: 3, Total CT: 1.060412883758545
#
# ==============================================================
# Scene: test_69_83474
# CBS total CT: 30.29938769340515
#
# test_69_83474
# CBS result!
# Cost: 1577, Gen nodes: 365, Exp nodes: 183, total CT: 30.29938769340515
# ICBS result!
# Cost: 1577, Gen nodes: 362, Exp nodes: 183, total CT: 87.4192008972168
# Learned_CBS results!
# Cost: 1577, Gen_nodes: 177, Exp_nodes: 89, Total CT: 12.228660106658936
#
# ==============================================================
# Scene: test_69_89438
# CBS total CT: 37.468364000320435
#
# test_69_89438
# CBS result!
# Cost: 1594, Gen nodes: 149, Exp nodes: 75, total CT: 37.468364000320435
# ICBS result!
# Cost: 1594, Gen nodes: 53, Exp nodes: 29, total CT: 84.9068853855133
# Learned_CBS results!
# Cost: 1594, Gen_nodes: 5, Exp_nodes: 3, Total CT: 3.3804898262023926
#
# ==============================================================
# Scene: test_69_86079
# CBS total CT: 6.468573093414307
#
# test_69_86079
# CBS result!
# Cost: 1705, Gen nodes: 25, Exp nodes: 13, total CT: 6.468573093414307
# ICBS result!
# Cost: 1705, Gen nodes: 16, Exp nodes: 10, total CT: 19.057399034500122
# Learned_CBS results!
# Cost: 1705, Gen_nodes: 19, Exp_nodes: 10, Total CT: 0.9745073318481445
#
# ==============================================================
# Scene: test_69_81264
# CBS total CT: 15.783294200897217
#
# test_69_81264
# CBS result!
# Cost: 1963, Gen nodes: 139, Exp nodes: 70, total CT: 15.783294200897217
# ICBS result!
# Cost: 1963, Gen nodes: 70, Exp nodes: 39, total CT: 69.07298374176025
# Learned_CBS results!
# Cost: 1963, Gen_nodes: 9, Exp_nodes: 5, Total CT: 3.290916919708252
#
# ==============================================================
# Scene: test_69_88286
# CBS total CT: 166.94254207611084
#
# test_69_88286
# CBS result!
# Cost: 1693, Gen nodes: 1727, Exp nodes: 864, total CT: 166.94254207611084
# ICBS result!
# Cost: 1693, Gen nodes: 56, Exp nodes: 31, total CT: 31.95844531059265
# Learned_CBS results!
# Cost: 1693, Gen_nodes: 255, Exp_nodes: 128, Total CT: 11.306308507919312
#
# ==============================================================
# Scene: test_69_85244
# CBS total CT: 2.2397990226745605
#
# test_69_85244
# CBS result!
# Cost: 1374, Gen nodes: 29, Exp nodes: 15, total CT: 2.2397990226745605
# ICBS result!
# Cost: 1374, Gen nodes: 15, Exp nodes: 10, total CT: 6.589393854141235
# Learned_CBS results!
# Cost: 1374, Gen_nodes: 29, Exp_nodes: 15, Total CT: 1.1253206729888916
#
# ==============================================================
# Scene: test_69_87440
# CBS total CT: 6.641611814498901
#
# test_69_87440
# CBS result!
# Cost: 1871, Gen nodes: 95, Exp nodes: 48, total CT: 6.641611814498901
# ICBS result!
# Cost: 1871, Gen nodes: 16, Exp nodes: 10, total CT: 8.981704473495483
# Learned_CBS results!
# Cost: 1871, Gen_nodes: 7, Exp_nodes: 4, Total CT: 1.447554349899292
#
# ==============================================================
# Scene: test_69_83190
# CBS total CT: 8.786696195602417
#
# test_69_83190
# CBS result!
# Cost: 1694, Gen nodes: 25, Exp nodes: 13, total CT: 8.786696195602417
# ICBS result!
# Cost: 1694, Gen nodes: 8, Exp nodes: 6, total CT: 6.330138683319092
# Learned_CBS results!
# Cost: 1694, Gen_nodes: 33, Exp_nodes: 17, Total CT: 22.633819818496704
#
# ==============================================================
# Scene: test_69_84750
# CBS total CT: 95.88133072853088
#
# test_69_84750
# CBS result!
# Cost: 1614, Gen nodes: 1033, Exp nodes: 517, total CT: 95.88133072853088
# ICBS result!
# Cost: 1614, Gen nodes: 1027, Exp nodes: 517, total CT: 338.2630491256714
# Learned_CBS results!
# Cost: 1614, Gen_nodes: 7, Exp_nodes: 4, Total CT: 2.890502691268921
#
# ==============================================================
# Scene: test_69_80898
# CBS total CT: 4.304734468460083
#
# test_69_80898
# CBS result!
# Cost: 1578, Gen nodes: 29, Exp nodes: 15, total CT: 4.304734468460083
# ICBS result!
# Cost: 1578, Gen nodes: 9, Exp nodes: 7, total CT: 4.173738241195679
# Learned_CBS results!
# Cost: 1578, Gen_nodes: 11, Exp_nodes: 6, Total CT: 0.7884485721588135
#
# ==============================================================
# Scene: test_69_83938
# CBS total CT: 14.120777368545532
#
# test_69_83938
# CBS result!
# Cost: 1556, Gen nodes: 159, Exp nodes: 80, total CT: 14.120777368545532
# ICBS result!
# Cost: 1556, Gen nodes: 10, Exp nodes: 7, total CT: 6.097423553466797
# Learned_CBS results!
# Cost: 1556, Gen_nodes: 9, Exp_nodes: 5, Total CT: 0.5163002014160156
#
# ==============================================================
# Scene: test_69_88321
# CBS total CT: 54.01391077041626
#
# test_69_88321
# CBS result!
# Cost: 1566, Gen nodes: 31, Exp nodes: 16, total CT: 54.01391077041626
# ICBS result!
# Cost: 1566, Gen nodes: 10, Exp nodes: 8, total CT: 75.05587100982666
# Learned_CBS results!
# Cost: 1566, Gen_nodes: 13, Exp_nodes: 7, Total CT: 10.132877349853516
#
# ==============================================================
# Scene: test_69_88497
# CBS total CT: 87.7196249961853
#
# test_69_88497
# CBS result!
# Cost: 1804, Gen nodes: 23, Exp nodes: 12, total CT: 87.7196249961853
# ICBS result!
# Cost: 1804, Gen nodes: 10, Exp nodes: 8, total CT: 220.66936802864075
# Learned_CBS results!
# Cost: 1804, Gen_nodes: 29, Exp_nodes: 15, Total CT: 57.7598192691803
#
# ==============================================================
# Scene: test_69_87688
# CBS total CT: 231.60795164108276
#
# test_69_87688
# CBS result!
# Cost: 1887, Gen nodes: 5753, Exp nodes: 2877, total CT: 231.60795164108276
# ICBS result!
# Cost: 1887, Gen nodes: 126, Exp nodes: 64, total CT: 16.930908679962158
# Learned_CBS results!
# Cost: 1887, Gen_nodes: 9, Exp_nodes: 5, Total CT: 1.1386208534240723
#
# ==============================================================
# Scene: test_69_88273
# CBS total CT: 2.620853900909424
#
# test_69_88273
# CBS result!
# Cost: 1748, Gen nodes: 19, Exp nodes: 10, total CT: 2.620853900909424
# ICBS result!
# Cost: 1748, Gen nodes: 16, Exp nodes: 10, total CT: 11.007557153701782
# Learned_CBS results!
# Cost: 1748, Gen_nodes: 9, Exp_nodes: 5, Total CT: 1.2930011749267578
#
# ==============================================================
# Scene: test_69_82771
# CBS total CT: 2.765984535217285
#
# test_69_82771
# CBS result!
# Cost: 1661, Gen nodes: 19, Exp nodes: 10, total CT: 2.765984535217285
# ICBS result!
# Cost: 1661, Gen nodes: 10, Exp nodes: 7, total CT: 6.406442642211914
# Learned_CBS results!
# Cost: 1661, Gen_nodes: 9, Exp_nodes: 5, Total CT: 0.6859807968139648
#
# ==============================================================
# Scene: test_69_89699
# CBS total CT: 5.457242965698242
#
# test_69_89699
# CBS result!
# Cost: 1586, Gen nodes: 19, Exp nodes: 10, total CT: 5.457242965698242
# ICBS result!
# Cost: 1586, Gen nodes: 16, Exp nodes: 10, total CT: 13.959627389907837
# Learned_CBS results!
# Cost: 1586, Gen_nodes: 17, Exp_nodes: 9, Total CT: 5.5422327518463135
#
# ==============================================================
# Scene: test_69_81596
# CBS total CT: 95.9063651561737
#
# test_69_81596
# CBS result!
# Cost: 1793, Gen nodes: 909, Exp nodes: 455, total CT: 95.9063651561737
# ICBS result!
# Cost: 1793, Gen nodes: 83, Exp nodes: 44, total CT: 560.5722222328186
# Learned_CBS results!
# Cost: 1793, Gen_nodes: 231, Exp_nodes: 116, Total CT: 15.175105810165405
#
# ==============================================================
# Scene: test_69_83623
# CBS total CT: 3.160860061645508
#
# test_69_83623
# CBS result!
# Cost: 1937, Gen nodes: 33, Exp nodes: 17, total CT: 3.160860061645508
# ICBS result!
# Cost: 1937, Gen nodes: 16, Exp nodes: 10, total CT: 11.744416952133179
# Learned_CBS results!
# Cost: 1937, Gen_nodes: 31, Exp_nodes: 16, Total CT: 1.0906858444213867
#
# ==============================================================
# Scene: test_69_88302
# CBS total CT: 32.57053256034851
#
# test_69_88302
# CBS result!
# Cost: 1603, Gen nodes: 71, Exp nodes: 36, total CT: 32.57053256034851
# ICBS result!
# Cost: 1603, Gen nodes: 67, Exp nodes: 36, total CT: 86.31712865829468
# Learned_CBS results!
# Cost: 1603, Gen_nodes: 5, Exp_nodes: 3, Total CT: 11.412633180618286
#
# ==============================================================
# Scene: test_69_88592
# CBS total CT: 6.383889436721802
#
# test_69_88592
# CBS result!
# Cost: 1714, Gen nodes: 23, Exp nodes: 12, total CT: 6.383889436721802
# ICBS result!
# Cost: 1714, Gen nodes: 19, Exp nodes: 12, total CT: 17.034414529800415
# Learned_CBS results!
# Cost: 1714, Gen_nodes: 19, Exp_nodes: 10, Total CT: 2.5319879055023193
#
# ==============================================================
# Scene: test_69_84465
# CBS total CT: 8.074557542800903
#
# test_69_84465
# CBS result!
# Cost: 1666, Gen nodes: 29, Exp nodes: 15, total CT: 8.074557542800903
# ICBS result!
# Cost: 1666, Gen nodes: 16, Exp nodes: 10, total CT: 5.458163738250732
# Learned_CBS results!
# Cost: 1666, Gen_nodes: 29, Exp_nodes: 15, Total CT: 0.9944062232971191

# %%
import glob

# %%
# /home/railab/Workspace/CCBS/Train_results/Overfitting_test_69/cbs_results/test_69_110.txt
train_result_file_list = sorted(glob.glob("/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/*.txt"))
print(len(train_result_file_list))
train_result_file_list
# Out:
# 241
# ['/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80323.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80360.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80370.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80443.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80453.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80544.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80605.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80744.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80764.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80796.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80839.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80840.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80873.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80895.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80898.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80918.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80949.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_80961.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81017.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81069.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81086.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81092.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81264.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81284.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81315.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81335.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81387.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81430.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81433.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81438.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81465.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81467.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81468.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81475.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81567.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81587.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81596.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81649.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81699.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81720.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81777.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81805.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81839.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_81910.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82077.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82080.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82171.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82172.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82187.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82194.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82235.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82386.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82407.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82424.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82445.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82488.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82528.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82566.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82611.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82654.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82660.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82681.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82691.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82697.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82727.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82771.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82782.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82876.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82931.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82932.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82938.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_82976.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83049.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83074.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83112.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83163.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83177.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83190.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83208.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83212.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83225.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83256.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83294.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83295.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83322.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83366.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83441.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83474.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83487.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83549.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83618.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83623.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83645.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83790.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83876.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83912.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_83938.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84020.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84025.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84028.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84111.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84291.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84293.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84311.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84337.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84352.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84355.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84363.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84378.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84407.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84465.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84482.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84513.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84710.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84750.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84799.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84811.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84871.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_84897.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85191.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85212.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85243.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85244.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85255.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85291.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85491.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85498.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85518.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85582.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85620.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85657.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85703.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85718.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85725.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85785.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85816.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_85847.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86078.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86079.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86101.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86113.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86145.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86178.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86309.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86320.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86330.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86397.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86420.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86573.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86704.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86709.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86713.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86730.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86791.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86886.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86904.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86969.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86981.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_86995.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87021.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87056.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87069.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87239.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87352.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87388.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87400.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87440.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87451.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87454.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87477.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87532.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87554.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87656.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87680.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87688.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87724.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87730.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87806.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87841.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87897.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87928.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87951.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87960.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_87979.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88014.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88185.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88273.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88286.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88302.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88321.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88341.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88355.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88422.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88430.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88459.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88497.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88523.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88556.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88589.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88592.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88619.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88627.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88701.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88722.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88725.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88740.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88782.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88837.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88851.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88877.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88899.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88919.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_88924.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89001.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89087.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89128.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89145.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89161.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89176.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89186.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89311.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89312.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89325.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89328.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89422.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89438.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89447.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89476.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89521.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89651.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89665.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89699.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89700.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89759.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89810.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89815.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89821.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89880.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89905.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89914.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_69/learned_cbs_results/test_69_89940.txt']

# %%
total_cbs_cost = 0
total_cbs_gen_nodes = 0
total_cbs_exp_nodes = 0
total_cbs_CT = 0

total_icbs_cost = 0
total_icbs_gen_nodes = 0
total_icbs_exp_nodes = 0
total_icbs_CT = 0

total_lcbs_cost = 0
total_lcbs_gen_nodes = 0
total_lcbs_exp_nodes = 0
total_lcbs_CT = 0

for train_result_file in train_result_file_list:
    f = open(train_result_file, 'r')
    result = f.readlines()
    f.close()

    # print(result)

    # print(train_result_file)

    cbs_result = result[2]
    icbs_result = result[4]
    lcbs_result = result[6]

    cbs_cost = int(cbs_result.split(", ")[0].split(": ")[-1])
    cbs_gen_nodes = int(cbs_result.split(", ")[1].split(": ")[-1])
    cbs_exp_nodes = int(cbs_result.split(", ")[2].split(": ")[-1])
    cbs_total_CT = float(cbs_result.split(", ")[3].split(": ")[-1])

    icbs_cost = int(icbs_result.split(", ")[0].split(": ")[-1])
    icbs_gen_nodes = int(icbs_result.split(", ")[1].split(": ")[-1])
    icbs_exp_nodes = int(icbs_result.split(", ")[2].split(": ")[-1])
    icbs_total_CT = float(icbs_result.split(", ")[3].split(": ")[-1])

    lcbs_cost = int(lcbs_result.split(", ")[0].split(": ")[-1])
    lcbs_gen_nodes = int(lcbs_result.split(", ")[1].split(": ")[-1])
    lcbs_exp_nodes = int(lcbs_result.split(", ")[2].split(": ")[-1])
    lcbs_total_CT = float(lcbs_result.split(", ")[3].split(": ")[-1])

    total_cbs_cost += cbs_cost
    total_cbs_gen_nodes += cbs_gen_nodes
    total_cbs_exp_nodes += cbs_exp_nodes
    total_cbs_CT += cbs_total_CT

    total_icbs_cost += icbs_cost
    total_icbs_gen_nodes += icbs_gen_nodes
    total_icbs_exp_nodes += icbs_exp_nodes
    total_icbs_CT += icbs_total_CT

    total_lcbs_cost += lcbs_cost
    total_lcbs_gen_nodes += lcbs_gen_nodes
    total_lcbs_exp_nodes += lcbs_exp_nodes
    total_lcbs_CT += lcbs_total_CT

avg_cbs_cost = total_cbs_cost / len(train_result_file_list)
avg_cbs_gen_nodes = total_cbs_gen_nodes / len(train_result_file_list)
avg_cbs_exp_nodes = total_cbs_exp_nodes / len(train_result_file_list)
avg_cbs_CT = total_cbs_CT / len(train_result_file_list)

avg_icbs_cost = total_icbs_cost / len(train_result_file_list)
avg_icbs_gen_nodes = total_icbs_gen_nodes / len(train_result_file_list)
avg_icbs_exp_nodes = total_icbs_exp_nodes / len(train_result_file_list)
avg_icbs_CT = total_icbs_CT / len(train_result_file_list)

avg_lcbs_cost = total_lcbs_cost / len(train_result_file_list)
avg_lcbs_gen_nodes = total_lcbs_gen_nodes / len(train_result_file_list)
avg_lcbs_exp_nodes = total_lcbs_exp_nodes / len(train_result_file_list)
avg_lcbs_CT = total_lcbs_CT / len(train_result_file_list)

print("CBS\nAvg cost: {}, Avg gen nodes: {}, Avg exp nodes: {}, Avg CT: {}".format(avg_cbs_cost, avg_cbs_gen_nodes, avg_cbs_exp_nodes, avg_cbs_CT))
print("\nICBS\nAvg cost: {}, Avg gen nodes: {}, Avg exp nodes: {}, Avg CT: {}".format(avg_icbs_cost, avg_icbs_gen_nodes, avg_icbs_exp_nodes, avg_icbs_CT))
print("\nLCBS\nAvg cost: {}, Avg gen nodes: {}, Avg exp nodes: {}, Avg CT: {}".format(avg_lcbs_cost, avg_lcbs_gen_nodes, avg_lcbs_exp_nodes, avg_lcbs_CT))
# Out:
# CBS
# Avg cost: 1714.4813278008298, Avg gen nodes: 409.5809128630705, Avg exp nodes: 205.29045643153526, Avg CT: 35.43431121284042
#
# ICBS
# Avg cost: 1714.4813278008298, Avg gen nodes: 97.48547717842324, Avg exp nodes: 51.11618257261411, Avg CT: 77.27359811992567
#
# LCBS
# Avg cost: 1714.4813278008298, Avg gen nodes: 81.30705394190872, Avg exp nodes: 41.15352697095436, Avg CT: 6.387616885648229

# %% [markdown]
# PRIMAL

# %%
primal_result_paths = sorted(glob.glob("/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/*.txt"))
print(primal_result_paths)
# Out:
# ['/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80323.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80360.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80370.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80443.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80453.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80544.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80605.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80744.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80764.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80796.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80839.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80840.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80873.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80895.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80898.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80918.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80949.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_80961.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81017.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81069.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81086.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81092.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81264.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81284.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81315.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81335.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81387.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81430.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81433.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81438.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81465.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81467.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81468.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81475.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81567.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81587.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81596.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81649.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81695.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81699.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81720.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81777.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81805.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81839.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_81910.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_82077.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_82080.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/test_69_82171.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_69/t ...

# %%
optimal_cnt = 0
total_CT = 0
fail_cnt = 0

for primal_result_file in primal_result_paths:
    f = open(primal_result_file, 'r')
    primal_result = f.readlines()
    f.close()

    scene_name = primal_result_file.split("/")[-1][:-4]
    cbs_path = "/home/railab/Workspace/CCBS/Results/Making_heatmap/test_69/bigger_heatmap/nodes_dec/test_10/"
    cbs_result_path = cbs_path + scene_name + "_result.txt"

    f = open(cbs_result_path, 'r')
    cbs_result = f.readlines()
    f.close()


    primal_cost = int(primal_result[0].split(", ")[0].split(": ")[-1])
    primal_Done = int(primal_result[0].split(", ")[1].split(": ")[-1])
    primal_CT = float(primal_result[0].split(", ")[-1].split(": ")[-1])

    if primal_Done != 20:
        fail_cnt += 1
        continue

    cbs_cost = int(cbs_result[2].split(', ')[0].split(": ")[-1])
    
    if primal_cost == cbs_cost:
        optimal_cnt += 1
    
    total_CT += primal_CT

avg_primal_CT = total_CT/len(primal_result_paths)
success_rate = (len(primal_result_paths) - fail_cnt) / len(primal_result_paths) * 100
optimal_rate = optimal_cnt / len(primal_result_paths) * 100

print("64x64 result\nComputation time: {}, Success rate: {}, Optimal rate: {}".format(avg_primal_CT, success_rate, optimal_rate))
# Out:
# 64x64 result
# Computation time: 19.623749688023427, Success rate: 99.59016393442623, Optimal rate: 0.0
