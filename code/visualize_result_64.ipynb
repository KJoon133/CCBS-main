# %%
import os, random, glob, sys
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

torch.set_printoptions(threshold=sys.maxsize)
torch.set_printoptions(linewidth=sys.maxsize)

np.set_printoptions(threshold=sys.maxsize)
np.set_printoptions(linewidth=sys.maxsize)

from core.model.models import cnn_mlp_64 
from core.model.Unet import UNet_2D_64
from core.utils.utils import import_mapf_instance, inverse_sigmoid, get_scene_80, get_sum_of_cost, get_cbs_result, visualize_heatmap
from core.func.cbs_basic import CBSSolver, CBSSolver_Cost_Plot, CBSSolver_Cost

# %%
def dense_input_data(starts, goals):
    input_data = []

    all_data = [(sx, sy, gx, gy) for (sx, sy), (gx, gy) in zip(starts, goals)]

    for i, (start, goal) in enumerate(zip(starts, goals)):
        sx, sy = start
        gx, gy = goal
        dx, dy = gx-sx, gy-sy
        mag = np.sqrt(dx ** 2 + dy ** 2)

        if mag != 0:
            dx = dx / mag
            dy = dy / mag

        except_agent_data = all_data[:i] + all_data[i+1:]

        own_data = [sx, sy, gx, gy, dx, dy, mag]

        for (other_sx, other_sy, other_gx, other_gy) in except_agent_data:
            other_dx, other_dy = other_gx-other_sx, other_gy-other_sy
            other_mag = np.sqrt(other_dx ** 2 + other_dy ** 2)

            if other_mag != 0:
                other_dx = other_dx / other_mag
                other_dy = other_dy / other_mag

            own_data += [other_sx-sx, other_sy-sy, other_dx, other_dy, other_mag]

        own_data = np.array(own_data)
        input_data.append(own_data)
    
    return np.array(input_data)

# %% [markdown]
# Sorted_Normalized_no_vertex

# %%
train_scene_list = sorted(get_scene_80("test_70", "bigger_heatmap", dataset='train'))
test_scene_list = sorted(get_scene_80("test_70", "bigger_heatmap", dataset="test"))
method = "bigger_heatmap"
device = "cuda:0" if torch.cuda.is_available() else 'cpu'
print("device: {}".format(device))
# Out:
# Total 2007 data loaded for train!
# Total 317 data loaded for test!
# device: cuda:0

# %%
model = UNet_2D_64(2, 1, 102)
# model = cnn_mlp_64(102, 4096)
mseloss = nn.MSELoss()

model_name = "unet_64"
loss_name = mseloss._get_name()

# /home/railab/Workspace/CCBS/code/model_params/unet/MSELoss/L2_None/batch_32_lr_0.0001_epoch_1.pt
save_path = "/home/railab/Workspace/CCBS/code/model_params/{}/{}/L2_None".format(model_name, loss_name)

if os.path.exists(save_path):
    saved_model_list = glob.glob(save_path + "/batch*")
    saved_model_list.sort(key= lambda x : int(x.split("_")[-1][:-4]))
    last_model_file_name = saved_model_list[-1]
    previous_epochs = int(last_model_file_name.split("_")[-1][:-4])
else:
    previous_epochs = 0
    loss_list = []
    print("There is no trained model!")

print("Model: {}\nLoss: {}\n".format(model_name, loss_name))
# Out:
# Model: unet_64
# Loss: MSELoss

# %%
model.load_state_dict(torch.load(last_model_file_name))
# Out:
# <All keys matched successfully>

# %%
avg_loss = 0.
model.eval()

for i, scene in enumerate(test_scene_list):
    # Get data
    test_name = scene.split("/")[-2]
    scene_name = scene.split("/")[-1][:-4]

    total_result_file_name = "/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/" + scene_name + ".txt"

    if os.path.exists(total_result_file_name):
        continue

    map, starts, goals = import_mapf_instance(scene)
    agent_num = len(starts)

    obs_map = np.array([[int(val) for val in sublist] for sublist in map])
    obs_map = np.repeat(obs_map[np.newaxis,:,:], agent_num, axis=0)

    heatmap_path = "/home/railab/Workspace/CCBS/code/costmaps/Gaussian_Blur/{}_heatmap/bigger_heatmap/{}.npy".format(test_name, scene_name)
    heatmap_data = np.load(heatmap_path, allow_pickle=True)

    h_map_path = "/home/railab/Workspace/CCBS/code/h_value_maps/{}/bigger_heatmap/{}.npy".format(test_name, scene_name)
    h_map_array = np.load(h_map_path, allow_pickle=True)

    input_data = dense_input_data(np.array(starts), np.array(goals))

    obs_map = torch.reshape(torch.Tensor(obs_map), heatmap_data.shape)
    h_val_map = torch.reshape(torch.Tensor(h_map_array), heatmap_data.shape)

    conv_data = torch.cat((obs_map, h_val_map), axis=1)

    input_data = torch.Tensor(input_data)

    pred = model(conv_data, input_data)
    pred = torch.reshape(pred, heatmap_data.shape)
    pred = torch.sigmoid(pred)
    # loss = mseloss(pred, torch.Tensor(heatmap_data))
    # print(loss)

    pred = pred.detach().numpy()

    pred = np.where(pred<1e-3, 0, pred)

    # print(pred)
    # print(heatmap_data)

    # print(pred.shape)
    # print(heatmap_data.shape)

    
    # /home/railab/Workspace/CCBS/code/instances/gen_test/test_69
    result_file_path = "/home/railab/Workspace/CCBS/code/instances/gen_test/{}/{}.txt".format(test_name, scene_name)
    print("==============================================================")
    print("Scene: {}".format(scene_name))

    f = open(result_file_path, 'r')
    contents = f.readlines()
    cbs_result = contents[1] + contents[2].rstrip()
    f.close()

    print("CBS " + contents[2].split(", ")[-1])
    
    # cbs_gen_nodes = int(contents[2].split(", ")[1].split(": ")[1])
    # cbs_exp_nodes = int(contents[2].split(", ")[2].split(": ")[1])

    # target_solver = CBSSolver_Cost(map, starts, goals, heatmap_data)
    # target_path, target_gen_nodes, target_exp_nodes, target_total_CT = target_solver.find_solution()
    # target_cost = get_sum_of_cost(target_path)

    # target_result = "\nTarget results!\nCost: {}, Gen_nodes: {}, Exp_nodes: {}, Total CT: {}".format(target_cost, target_gen_nodes, target_exp_nodes, target_total_CT)
    # print(target_result)

    # visualize_heatmap(heatmap_data, "target")
    # visualize_heatmap(pred, 'pred')

    l_cbs_solver = CBSSolver_Cost(map, starts, goals, pred)
    l_cbs_path, l_cbs_gen_nodes, l_cbs_exp_nodes, l_cbs_total_CT = l_cbs_solver.find_solution()

    if l_cbs_path != None:

        l_cbs_cost = get_sum_of_cost(l_cbs_path)

        l_cbs_result = "\nLearned_CBS results!\nCost: {}, Gen_nodes: {}, Exp_nodes: {}, Total CT: {}\n".format(l_cbs_cost, l_cbs_gen_nodes, l_cbs_exp_nodes, l_cbs_total_CT)
        total_result = "".join(contents) + l_cbs_result
        print(total_result)

        total_result_file_name = "/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/" + scene_name + ".txt"
        f = open(total_result_file_name, "w")
        f.write(total_result)
        f.close()
    else:
        continue
# Out:
# ==============================================================
# Scene: test_70_22711
# CBS total CT: 39.47058916091919
#
# test_70_22711
# CBS result!
# Cost: 932, Gen nodes: 6383, Exp nodes: 3192, total CT: 39.47058916091919
# ICBS result!
# Cost: 932, Gen nodes: 42, Exp nodes: 23, total CT: 1.6799156665802002
# Learned_CBS results!
# Cost: 932, Gen_nodes: 7983, Exp_nodes: 3992, Total CT: 54.00904703140259
#
# ==============================================================
# Scene: test_70_22713
# CBS total CT: 0.5846779346466064
#
# test_70_22713
# CBS result!
# Cost: 912, Gen nodes: 21, Exp nodes: 11, total CT: 0.5846779346466064
# ICBS result!
# Cost: 912, Gen nodes: 12, Exp nodes: 10, total CT: 2.0808002948760986
# Learned_CBS results!
# Cost: 912, Gen_nodes: 11, Exp_nodes: 6, Total CT: 0.610588788986206
#
# ==============================================================
# Scene: test_70_22718
# CBS total CT: 2.1590471267700195
#
# test_70_22718
# CBS result!
# Cost: 913, Gen nodes: 191, Exp nodes: 96, total CT: 2.1590471267700195
# ICBS result!
# Cost: 913, Gen nodes: 125, Exp nodes: 65, total CT: 4.3659138679504395
# Learned_CBS results!
# Cost: 913, Gen_nodes: 133, Exp_nodes: 67, Total CT: 1.922572374343872
#
# ==============================================================
# Scene: test_70_22730
# CBS total CT: 1.5412731170654297
#
# test_70_22730
# CBS result!
# Cost: 983, Gen nodes: 21, Exp nodes: 11, total CT: 1.5412731170654297
# ICBS result!
# Cost: 983, Gen nodes: 13, Exp nodes: 11, total CT: 5.967461824417114
# Learned_CBS results!
# Cost: 983, Gen_nodes: 25, Exp_nodes: 13, Total CT: 1.357285499572754
#
# ==============================================================
# Scene: test_70_22732
# CBS total CT: 1.3318662643432617
#
# test_70_22732
# CBS result!
# Cost: 600, Gen nodes: 27, Exp nodes: 14, total CT: 1.3318662643432617
# ICBS result!
# Cost: 600, Gen nodes: 12, Exp nodes: 8, total CT: 2.2552669048309326
# Learned_CBS results!
# Cost: 600, Gen_nodes: 27, Exp_nodes: 14, Total CT: 1.683366060256958
#
# ==============================================================
# Scene: test_70_22747
# CBS total CT: 0.5610389709472656
#
# test_70_22747
# CBS result!
# Cost: 834, Gen nodes: 39, Exp nodes: 20, total CT: 0.5610389709472656
# ICBS result!
# Cost: 834, Gen nodes: 19, Exp nodes: 16, total CT: 4.661703824996948
# Learned_CBS results!
# Cost: 834, Gen_nodes: 33, Exp_nodes: 17, Total CT: 0.590980052947998
#
# ==============================================================
# Scene: test_70_22760
# CBS total CT: 2.5956947803497314
#
# test_70_22760
# CBS result!
# Cost: 799, Gen nodes: 21, Exp nodes: 11, total CT: 2.5956947803497314
# ICBS result!
# Cost: 799, Gen nodes: 11, Exp nodes: 10, total CT: 9.149147272109985
# Learned_CBS results!
# Cost: 799, Gen_nodes: 17, Exp_nodes: 9, Total CT: 3.2893288135528564
#
# ==============================================================
# Scene: test_70_22769
# CBS total CT: 1.271859884262085
#
# test_70_22769
# CBS result!
# Cost: 969, Gen nodes: 19, Exp nodes: 10, total CT: 1.271859884262085
# ICBS result!
# Cost: 969, Gen nodes: 7, Exp nodes: 6, total CT: 1.8079493045806885
# Learned_CBS results!
# Cost: 969, Gen_nodes: 5, Exp_nodes: 3, Total CT: 0.26562047004699707
#
# ==============================================================
# Scene: test_70_22772
# CBS total CT: 2.1626346111297607
#
# test_70_22772
# CBS result!
# Cost: 1103, Gen nodes: 23, Exp nodes: 12, total CT: 2.1626346111297607
# ICBS result!
# Cost: 1103, Gen nodes: 14, Exp nodes: 12, total CT: 8.603267669677734
# Learned_CBS results!
# Cost: 1103, Gen_nodes: 21, Exp_nodes: 11, Total CT: 2.7690234184265137
#
# ==============================================================
# Scene: test_70_22779
# CBS total CT: 0.41348862648010254
#
# test_70_22779
# CBS result!
# Cost: 871, Gen nodes: 21, Exp nodes: 11, total CT: 0.41348862648010254
# ICBS result!
# Cost: 871, Gen nodes: 13, Exp nodes: 11, total CT: 1.938744068145752
# Learned_CBS results!
# Cost: 871, Gen_nodes: 17, Exp_nodes: 9, Total CT: 0.4832184314727783
#
# ==============================================================
# Scene: test_70_22781
# CBS total CT: 0.29380249977111816
#
# test_70_22781
# CBS result!
# Cost: 776, Gen nodes: 19, Exp nodes: 10, total CT: 0.29380249977111816
# ICBS result!
# Cost: 776, Gen nodes: 10, Exp nodes: 8, total CT: 0.6382520198822021
# Learned_CBS results!
# Cost: 776, Gen_nodes: 15, Exp_nodes: 8, Total CT: 0.30629897117614746
#
# ==============================================================
# Scene: test_70_22787
# CBS total CT: 1.2017641067504883
#
# test_70_22787
# CBS result!
# Cost: 941, Gen nodes: 21, Exp nodes: 11, total CT: 1.2017641067504883
# ICBS result!
# Cost: 941, Gen nodes: 12, Exp nodes: 10, total CT: 6.282120943069458
# Learned_CBS results!
# Cost: 941, Gen_nodes: 13, Exp_nodes: 7, Total CT: 0.4705009460449219
#
# ==============================================================
# Scene: test_70_22792
# CBS total CT: 1.3874003887176514
#
# test_70_22792
# CBS result!
# Cost: 876, Gen nodes: 19, Exp nodes: 10, total CT: 1.3874003887176514
# ICBS result!
# Cost: 876, Gen nodes: 10, Exp nodes: 9, total CT: 7.430880546569824
# Learned_CBS results!
# Cost: 876, Gen_nodes: 19, Exp_nodes: 10, Total CT: 1.6507833003997803
#
# ==============================================================
# Scene: test_70_22793
# CBS total CT: 0.34618425369262695
#
# test_70_22793
# CBS result!
# Cost: 863, Gen nodes: 19, Exp nodes: 10, total CT: 0.34618425369262695
# ICBS result!
# Cost: 863, Gen nodes: 15, Exp nodes: 10, total CT: 1.1730005741119385
# Learned_CBS results!
# Cost: 863, Gen_nodes: 25, Exp_nodes: 13, Total CT: 0.6479053497314453
#
# ==============================================================
# Scene: test_70_22817
# CBS total CT: 0.44536328315734863
#
# test_70_22817
# CBS result!
# Cost: 995, Gen nodes: 19, Exp nodes: 10, total CT: 0.44536328315734863
# ICBS result!
# Cost: 995, Gen nodes: 10, Exp nodes: 10, total CT: 2.4991657733917236
# Learned_CBS results!
# Cost: 995, Gen_nodes: 15, Exp_nodes: 8, Total CT: 0.43546009063720703
#
# ==============================================================
# Scene: test_70_22824
# CBS total CT: 1.0957362651824951
#
# test_70_22824
# CBS result!
# Cost: 798, Gen nodes: 19, Exp nodes: 10, total CT: 1.0957362651824951
# ICBS result!
# Cost: 798, Gen nodes: 7, Exp nodes: 5, total CT: 1.8705942630767822
# Learned_CBS results!
# Cost: 798, Gen_nodes: 19, Exp_nodes: 10, Total CT: 1.4929630756378174
#
# ==============================================================
# Scene: test_70_22837
# CBS total CT: 0.43027544021606445
#
# test_70_22837
# CBS result!
# Cost: 941, Gen nodes: 23, Exp nodes: 12, total CT: 0.43027544021606445
# ICBS result!
# Cost: 941, Gen nodes: 20, Exp nodes: 12, total CT: 1.7781665325164795
# Learned_CBS results!
# Cost: 941, Gen_nodes: 9, Exp_nodes: 5, Total CT: 0.25358152389526367
#
# ==============================================================
# Scene: test_70_22854
# CBS total CT: 2.324502468109131
#
# test_70_22854
# CBS result!
# Cost: 804, Gen nodes: 53, Exp nodes: 27, total CT: 2.324502468109131
# ICBS result!
# Cost: 804, Gen nodes: 10, Exp nodes: 8, total CT: 1.3555574417114258
# Learned_CBS results!
# Cost: 804, Gen_nodes: 15, Exp_nodes: 8, Total CT: 0.7829084396362305
#
# ==============================================================
# Scene: test_70_22859
# CBS total CT: 3.1607863903045654
#
# test_70_22859
# CBS result!
# Cost: 827, Gen nodes: 163, Exp nodes: 82, total CT: 3.1607863903045654
# ICBS result!
# Cost: 827, Gen nodes: 21, Exp nodes: 15, total CT: 3.6053833961486816
# Learned_CBS results!
# Cost: 827, Gen_nodes: 89, Exp_nodes: 45, Total CT: 2.4391376972198486
#
# ==============================================================
# Scene: test_70_22864
# CBS total CT: 178.3028678894043
#
# test_70_22864
# CBS result!
# Cost: 824, Gen nodes: 34177, Exp nodes: 17089, total CT: 178.3028678894043
# ICBS result!
# Cost: 824, Gen nodes: 133, Exp nodes: 69, total CT: 19.5742027759552
# Learned_CBS results!
# Cost: 824, Gen_nodes: 283, Exp_nodes: 142, Total CT: 1.6124701499938965
#
# ==============================================================
# Scene: test_70_22879
# CBS total CT: 0.8470633029937744
#
# test_70_22879
# CBS result!
# Cost: 863, Gen nodes: 19, Exp nodes: 10, total CT: 0.8470633029937744
# ICBS result!
# Cost: 863, Gen nodes: 11, Exp nodes: 10, total CT: 3.6088707447052
# Learned_CBS results!
# Cost: 863, Gen_nodes: 9, Exp_nodes: 5, Total CT: 1.1147477626800537
#
# ==============================================================
# Scene: test_70_22894
# CBS total CT: 0.38176727294921875
#
# test_70_22894
# CBS result!
# Cost: 724, Gen nodes: 23, Exp nodes: 12, total CT: 0.38176727294921875
# ICBS result!
# Cost: 724, Gen nodes: 13, Exp nodes: 10, total CT: 1.0538146495819092
# Learned_CBS results!
# Cost: 724, Gen_nodes: 29, Exp_nodes: 15, Total CT: 0.4779689311981201
#
# ==============================================================
# Scene: test_70_22900
# CBS total CT: 0.9493019580841064
#
# test_70_22900
# CBS result!
# Cost: 883, Gen nodes: 21, Exp nodes: 11, total CT: 0.9493019580841064
# ICBS result!
# Cost: 883, Gen nodes: 11, Exp nodes: 9, total CT: 1.9179580211639404
# Learned_CBS results!
# Cost: 883, Gen_nodes: 13, Exp_nodes: 7, Total CT: 0.3407313823699951
#
# ==============================================================
# Scene: test_70_22904
# CBS total CT: 0.5333223342895508
#
# test_70_22904
# CBS result!
# Cost: 919, Gen nodes: 43, Exp nodes: 22, total CT: 0.5333223342895508
# ICBS result!
# Cost: 919, Gen nodes: 17, Exp nodes: 11, total CT: 1.2447452545166016
# Learned_CBS results!
# Cost: 919, Gen_nodes: 39, Exp_nodes: 20, Total CT: 0.6275875568389893
#
# ==============================================================
# Scene: test_70_22911
# CBS total CT: 0.4716758728027344
#
# test_70_22911
# CBS result!
# Cost: 801, Gen nodes: 35, Exp nodes: 18, total CT: 0.4716758728027344
# ICBS result!
# Cost: 801, Gen nodes: 15, Exp nodes: 9, total CT: 0.7754998207092285
# Learned_CBS results!
# Cost: 801, Gen_nodes: 5, Exp_nodes: 3, Total CT: 0.23037481307983398
#
# ==============================================================
# Scene: test_70_22912
# CBS total CT: 0.6730833053588867
#
# test_70_22912
# CBS result!
# Cost: 757, Gen nodes: 97, Exp nodes: 49, total CT: 0.6730833053588867
# ICBS result!
# Cost: 757, Gen nodes: 40, Exp nodes: 21, total CT: 0.8684370517730713
# Learned_CBS results!
# Cost: 757, Gen_nodes: 27, Exp_nodes: 14, Total CT: 0.2695472240447998
#
# ==============================================================
# Scene: test_70_22921
# CBS total CT: 2.163644552230835
#
# test_70_22921
# CBS result!
# Cost: 1056, Gen nodes: 31, Exp nodes: 16, total CT: 2.163644552230835
# ICBS result!
# Cost: 1056, Gen nodes: 15, Exp nodes: 13, total CT: 7.013281345367432
# Learned_CBS results!
# Cost: 1056, Gen_nodes: 25, Exp_nodes: 13, Total CT: 3.1077747344970703
#
# ==============================================================
# Scene: test_70_22928
# CBS total CT: 7.83096170425415
#
# test_70_22928
# CBS result!
# Cost: 839, Gen nodes: 875, Exp nodes: 438, total CT: 7.83096170425415
# ICBS result!
# Cost: 839, Gen nodes: 23, Exp nodes: 15, total CT: 3.0696866512298584
# Learned_CBS results!
# Cost: 839, Gen_nodes: 55, Exp_nodes: 28, Total CT: 0.7035789489746094
#
# ==============================================================
# Scene: test_70_22937
# CBS total CT: 0.7219924926757812
#
# test_70_22937
# CBS result!
# Cost: 962, Gen nodes: 35, Exp nodes: 18, total CT: 0.7219924926757812
# ICBS result!
# Cost: 962, Gen nodes: 17, Exp nodes: 12, total CT: 2.218954086303711
# Learned_CBS results!
# Cost: 962, Gen_nodes: 33, Exp_nodes: 17, Total CT: 0.8558871746063232
#
# ==============================================================
# Scene: test_70_22943
# CBS total CT: 0.47626233100891113
#
# test_70_22943
# CBS result!
# Cost: 846, Gen nodes: 51, Exp nodes: 26, total CT: 0.47626233100891113
# ICBS result!
# Cost: 846, Gen nodes: 11, Exp nodes: 8, total CT: 0.7640876770019531
# Learned_CBS results!
# Cost: 846, Gen_nodes: 39, Exp_nodes: 20, Total CT: 1.2253975868225098
#
# ==============================================================
# Scene: test_70_22945
# CBS total CT: 0.7680907249450684
#
# test_70_22945
# CBS result!
# Cost: 780, Gen nodes: 25, Exp nodes: 13, total CT: 0.7680907249450684
# ICBS result!
# Cost: 780, Gen nodes: 12, Exp nodes: 10, total CT: 3.210174798965454
# Learned_CBS results!
# Cost: 780, Gen_nodes: 13, Exp_nodes: 7, Total CT: 0.6779720783233643
#
# ==============================================================
# Scene: test_70_22946
# CBS total CT: 1.1993842124938965
#
# test_70_22946
# CBS result!
# Cost: 744, Gen nodes: 253, Exp nodes: 127, total CT: 1.1993842124938965
# ICBS result!
# Cost: 744, Gen nodes: 43, Exp nodes: 25, total CT: 1.2388455867767334
# Learned_CBS results!
# Cost: 744, Gen_nodes: 55, Exp_nodes: 28, Total CT: 1.0112276077270508
#
# ==============================================================
# Scene: test_70_22951
# CBS total CT: 1.3347413539886475
#
# test_70_22951
# CBS result!
# Cost: 832, Gen nodes: 19, Exp nodes: 10, total CT: 1.3347413539886475
# ICBS result!
# Cost: 832, Gen nodes: 9, Exp nodes: 8, total CT: 3.2429139614105225
# Learned_CBS results!
# Cost: 832, Gen_nodes: 13, Exp_nodes: 7, Total CT: 1.390458106994629
#
# ==============================================================
# Scene: test_70_22954
# CBS total CT: 0.2449815273284912
#
# test_70_22954
# CBS result!
# Cost: 755, Gen nodes: 27, Exp nodes: 14, total CT: 0.2449815273284912
# ICBS result!
# Cost: 755, Gen nodes: 23, Exp nodes: 14, total CT: 0.8197624683380127
# Learned_CBS results!
# Cost: 755, Gen_nodes: 141, Exp_nodes: 71, Total CT: 1.2910830974578857
#
# ==============================================================
# Scene: test_70_22955
# CBS total CT: 2.6168603897094727
#
# test_70_22955
# CBS result!
# Cost: 951, Gen nodes: 77, Exp nodes: 39, total CT: 2.6168603897094727
# ICBS result!
# Cost: 951, Gen nodes: 69, Exp nodes: 37, total CT: 5.758068799972534
# Learned_CBS results!
# Cost: 951, Gen_nodes: 77, Exp_nodes: 39, Total CT: 3.383866786956787
#
# ==============================================================
# Scene: test_70_22961
# CBS total CT: 221.73145127296448
#
# test_70_22961
# CBS result!
# Cost: 902, Gen nodes: 9103, Exp nodes: 4552, total CT: 221.73145127296448
# ICBS result!
# Cost: 902, Gen nodes: 102, Exp nodes: 55, total CT: 10.181825399398804
# Learned_CBS results!
# Cost: 902, Gen_nodes: 749, Exp_nodes: 375, Total CT: 5.849183797836304
#
# ==============================================================
# Scene: test_70_22968
# CBS total CT: 99.44064378738403
#
# test_70_22968
# CBS result!
# Cost: 844, Gen nodes: 7609, Exp nodes: 3805, total CT: 99.44064378738403
# ICBS result!
# Cost: 844, Gen nodes: 86, Exp nodes: 46, total CT: 8.155523538589478
# Learned_CBS results!
# Cost: 844, Gen_nodes: 4415, Exp_nodes: 2208, Total CT: 43.40866708755493
#
# ==============================================================
# Scene: test_70_22973
# CBS total CT: 0.4765188694000244
#
# test_70_22973
# CBS result!
# Cost: 748, Gen nodes: 27, Exp nodes: 14, total CT: 0.4765188694000244
# ICBS result!
# Cost: 748, Gen nodes: 17, Exp nodes: 11, total CT: 1.0154571533203125
# Learned_CBS results!
# Cost: 748, Gen_nodes: 23, Exp_nodes: 12, Total CT: 1.1011817455291748
#
# ==============================================================
# Scene: test_70_22974
# CBS total CT: 291.24827766418457
#
# test_70_22974
# CBS result!
# Cost: 868, Gen nodes: 39827, Exp nodes: 19914, total CT: 291.24827766418457
# ICBS result!
# Cost: 868, Gen nodes: 424, Exp nodes: 215, total CT: 20.51155424118042
# Learned_CBS results!
# Cost: 868, Gen_nodes: 55, Exp_nodes: 28, Total CT: 0.48511695861816406
#
# ==============================================================
# Scene: test_70_22977
# CBS total CT: 91.49740552902222
#
# test_70_22977
# CBS result!
# Cost: 850, Gen nodes: 5653, Exp nodes: 2827, total CT: 91.49740552902222
# ICBS result!
# Cost: 850, Gen nodes: 72, Exp nodes: 39, total CT: 7.39426064491272
# Learned_CBS results!
# Cost: 850, Gen_nodes: 683, Exp_nodes: 342, Total CT: 17.909273862838745
#
# ==============================================================
# Scene: test_70_22988
# CBS total CT: 0.3611929416656494
#
# test_70_22988
# CBS result!
# Cost: 936, Gen nodes: 23, Exp nodes: 12, total CT: 0.3611929416656494
# ICBS result!
# Cost: 936, Gen nodes: 17, Exp nodes: 13, total CT: 3.536726474761963
# Learned_CBS results!
# Cost: 936, Gen_nodes: 15, Exp_nodes: 8, Total CT: 0.3713870048522949
#
# ==============================================================
# Scene: test_70_22998
# CBS total CT: 0.8904728889465332
#
# test_70_22998
# CBS result!
# Cost: 870, Gen nodes: 41, Exp nodes: 21, total CT: 0.8904728889465332
# ICBS result!
# Cost: 870, Gen nodes: 38, Exp nodes: 22, total CT: 3.6303184032440186
# Learned_CBS results!
# Cost: 870, Gen_nodes: 41, Exp_nodes: 21, Total CT: 1.5789542198181152
#
# ==============================================================
# Scene: test_70_23016
# CBS total CT: 1.3095431327819824
#
# test_70_23016
# CBS result!
# Cost: 950, Gen nodes: 65, Exp nodes: 33, total CT: 1.3095431327819824
# ICBS result!
# Cost: 950, Gen nodes: 17, Exp nodes: 11, total CT: 2.868953227996826
# Learned_CBS results!
# Cost: 950, Gen_nodes: 35, Exp_nodes: 18, Total CT: 1.6737501621246338
#
# ==============================================================
# Scene: test_70_23018
# CBS total CT: 2.1249632835388184
#
# test_70_23018
# CBS result!
# Cost: 903, Gen nodes: 23, Exp nodes: 12, total CT: 2.1249632835388184
# ICBS result!
# Cost: 903, Gen nodes: 12, Exp nodes: 12, total CT: 8.69772458076477
# Learned_CBS results!
# Cost: 903, Gen_nodes: 11, Exp_nodes: 6, Total CT: 2.7747962474823
#
# ==============================================================
# Scene: test_70_23026
# CBS total CT: 1.1354670524597168
#
# test_70_23026
# CBS result!
# Cost: 820, Gen nodes: 29, Exp nodes: 15, total CT: 1.1354670524597168
# ICBS result!
# Cost: 820, Gen nodes: 11, Exp nodes: 9, total CT: 3.5182979106903076
# Learned_CBS results!
# Cost: 820, Gen_nodes: 11, Exp_nodes: 6, Total CT: 1.1951797008514404
#
# ==============================================================
# Scene: test_70_23030
# CBS total CT: 0.9876446723937988
#
# test_70_23030
# CBS result!
# Cost: 815, Gen nodes: 79, Exp nodes: 40, total CT: 0.9876446723937988
# ICBS result!
# Cost: 815, Gen nodes: 72, Exp nodes: 39, total CT: 3.9965012073516846
# Learned_CBS results!
# Cost: 815, Gen_nodes: 33, Exp_nodes: 17, Total CT: 0.8837897777557373
#
# ==============================================================
# Scene: test_70_23031
# CBS total CT: 75.91957879066467
#
# test_70_23031
# CBS result!
# Cost: 830, Gen nodes: 12351, Exp nodes: 6176, total CT: 75.91957879066467
# ICBS result!
# Cost: 830, Gen nodes: 39, Exp nodes: 23, total CT: 4.562114477157593
# Learned_CBS results!
# Cost: 830, Gen_nodes: 12351, Exp_nodes: 6176, Total CT: 79.23608326911926
#
# ==============================================================
# Scene: test_70_23033
# CBS total CT: 4.078390598297119
#
# test_70_23033
# CBS result!
# Cost: 857, Gen nodes: 559, Exp nodes: 280, total CT: 4.078390598297119
# ICBS result!
# Cost: 857, Gen nodes: 15, Exp nodes: 10, total CT: 0.786489725112915
# Learned_CBS results!
# Cost: 857, Gen_nodes: 559, Exp_nodes: 280, Total CT: 5.443464040756226
#
# ==============================================================
# Scene: test_70_23046
# CBS total CT: 27.416276931762695
#
# test_70_23046
# CBS result!
# Cost: 780, Gen nodes: 4121, Exp nodes: 2061, total CT: 27.416276931762695
# ICBS result!
# Cost: 780, Gen nodes: 171, Exp nodes: 90, total CT: 13.85978388786316
# Learned_CBS results!
# Cost: 780, Gen_nodes: 1065, Exp_nodes: 533, Total CT: 9.305761814117432
#
# ==============================================================
# Scene: test_70_23051
# CBS total CT: 0.5978546142578125
#
# test_70_23051
# CBS result!
# Cost: 846, Gen nodes: 29, Exp nodes: 15, total CT: 0.5978546142578125
# ICBS result!
# Cost: 846, Gen nodes: 10, Exp nodes: 8, total CT: 1.4314937591552734
# Learned_CBS results!
# Cost: 846, Gen_nodes: 19, Exp_nodes: 10, Total CT: 0.5456504821777344
#
# ==============================================================
# Scene: test_70_23057
# CBS total CT: 5.125430107116699
#
# test_70_23057
# CBS result!
# Cost: 808, Gen nodes: 99, Exp nodes: 50, total CT: 5.125430107116699
# ICBS result!
# Cost: 808, Gen nodes: 14, Exp nodes: 9, total CT: 2.204042434692383
# Learned_CBS results!
# Cost: 808, Gen_nodes: 33, Exp_nodes: 17, Total CT: 2.5680065155029297
#
# ==============================================================
# Scene: test_70_23062
# CBS total CT: 1.1251468658447266
#
# test_70_23062
# CBS result!
# Cost: 986, Gen nodes: 43, Exp nodes: 22, total CT: 1.1251468658447266
# ICBS result!
# Cost: 986, Gen nodes: 17, Exp nodes: 12, total CT: 6.8272459506988525
# Learned_CBS results!
# Cost: 986, Gen_nodes: 33, Exp_nodes: 17, Total CT: 0.5109961032867432
#
# ==============================================================
# Scene: test_70_23079
# CBS total CT: 0.5452060699462891
#
# test_70_23079
# CBS result!
# Cost: 850, Gen nodes: 39, Exp nodes: 20, total CT: 0.5452060699462891
# ICBS result!
# Cost: 850, Gen nodes: 18, Exp nodes: 12, total CT: 100.19026947021484
# Learned_CBS results!
# Cost: 850, Gen_nodes: 51, Exp_nodes: 26, Total CT: 0.8235061168670654
#
# ==============================================================
# Scene: test_70_23082
# CBS total CT: 1.0348575115203857
#
# test_70_23082
# CBS result!
# Cost: 871, Gen nodes: 85, Exp nodes: 43, total CT: 1.0348575115203857
# ICBS result!
# Cost: 871, Gen nodes: 8, Exp nodes: 6, total CT: 0.5267584323883057
# Learned_CBS results!
# Cost: 871, Gen_nodes: 13, Exp_nodes: 7, Total CT: 0.28406500816345215
#
# ==============================================================
# Scene: test_70_23089
# CBS total CT: 9.202152252197266
#
# test_70_23089
# CBS result!
# Cost: 770, Gen nodes: 1033, Exp nodes: 517, total CT: 9.202152252197266
# ICBS result!
# Cost: 770, Gen nodes: 132, Exp nodes: 69, total CT: 4.140761852264404
# Learned_CBS results!
# Cost: 770, Gen_nodes: 81, Exp_nodes: 41, Total CT: 0.9140267372131348
#
# ==============================================================
# Scene: test_70_23098
# CBS total CT: 0.3807849884033203
#
# test_70_23098
# CBS result!
# Cost: 805, Gen nodes: 39, Exp nodes: 20, total CT: 0.3807849884033203
# ICBS result!
# Cost: 805, Gen nodes: 33, Exp nodes: 20, total CT: 1.4269945621490479
# Learned_CBS results!
# Cost: 805, Gen_nodes: 51, Exp_nodes: 26, Total CT: 0.43253326416015625
#
# ==============================================================
# Scene: test_70_23101
# CBS total CT: 0.48410677909851074
#
# test_70_23101
# CBS result!
# Cost: 930, Gen nodes: 31, Exp nodes: 16, total CT: 0.48410677909851074
# ICBS result!
# Cost: 930, Gen nodes: 18, Exp nodes: 12, total CT: 4.815930366516113
# Learned_CBS results!
# Cost: 930, Gen_nodes: 35, Exp_nodes: 18, Total CT: 0.6925995349884033
#
# ==============================================================
# Scene: test_70_23113
# CBS total CT: 10.479378938674927
#
# test_70_23113
# CBS result!
# Cost: 747, Gen nodes: 119, Exp nodes: 60, total CT: 10.479378938674927
# ICBS result!
# Cost: 747, Gen nodes: 13, Exp nodes: 11, total CT: 5.444702625274658
# Learned_CBS results!
# Cost: 747, Gen_nodes: 107, Exp_nodes: 54, Total CT: 11.86308217048645
#
# ==============================================================
# Scene: test_70_23122
# CBS total CT: 1.1541833877563477
#
# test_70_23122
# CBS result!
# Cost: 1068, Gen nodes: 27, Exp nodes: 14, total CT: 1.1541833877563477
# ICBS result!
# Cost: 1068, Gen nodes: 23, Exp nodes: 15, total CT: 3.2711143493652344
# Learned_CBS results!
# Cost: 1068, Gen_nodes: 29, Exp_nodes: 15, Total CT: 1.9607574939727783
#
# ==============================================================
# Scene: test_70_23126
# CBS total CT: 0.2977113723754883
#
# test_70_23126
# CBS result!
# Cost: 754, Gen nodes: 31, Exp nodes: 16, total CT: 0.2977113723754883
# ICBS result!
# Cost: 754, Gen nodes: 16, Exp nodes: 10, total CT: 1.2045154571533203
# Learned_CBS results!
# Cost: 754, Gen_nodes: 171, Exp_nodes: 86, Total CT: 1.2389178276062012
#
# ==============================================================
# Scene: test_70_23136
# CBS total CT: 94.81109738349915
#
# ==============================================================
# Scene: test_70_23147
# CBS total CT: 0.8598060607910156
#
# test_70_23147
# CBS result!
# Cost: 907, Gen nodes: 35, Exp nodes: 18, total CT: 0.8598060607910156
# ICBS result!
# Cost: 907, Gen nodes: 16, Exp nodes: 12, total CT: 2.2927145957946777
# Learned_CBS results!
# Cost: 907, Gen_nodes: 55, Exp_nodes: 28, Total CT: 1.7909491062164307
#
# ==============================================================
# Scene: test_70_23148
# CBS total CT: 22.431268215179443
#
# test_70_23148
# CBS result!
# Cost: 885, Gen nodes: 3145, Exp nodes: 1573, total CT: 22.431268215179443
# ICBS result!
# Cost: 885, Gen nodes: 22, Exp nodes: 13, total CT: 1.8675966262817383
# Learned_CBS results!
# Cost: 885, Gen_nodes: 235, Exp_nodes: 118, Total CT: 3.0804390907287598
#
# ==============================================================
# Scene: test_70_23171
# CBS total CT: 0.4314284324645996
#
# test_70_23171
# CBS result!
# Cost: 883, Gen nodes: 29, Exp nodes: 15, total CT: 0.4314284324645996
# ICBS result!
# Cost: 883, Gen nodes: 24, Exp nodes: 15, total CT: 1.4183831214904785
# Learned_CBS results!
# Cost: 883, Gen_nodes: 121, Exp_nodes: 61, Total CT: 1.1630892753601074
#
# ==============================================================
# Scene: test_70_23173
# CBS total CT: 116.21615719795227
#
# ==============================================================
# Scene: test_70_23176
# CBS total CT: 0.9970946311950684
#
# test_70_23176
# CBS result!
# Cost: 862, Gen nodes: 27, Exp nodes: 14, total CT: 0.9970946311950684
# ICBS result!
# Cost: 862, Gen nodes: 20, Exp nodes: 14, total CT: 8.456608533859253
# Learned_CBS results!
# Cost: 862, Gen_nodes: 21, Exp_nodes: 11, Total CT: 1.2684357166290283
#
# ==============================================================
# Scene: test_70_23189
# CBS total CT: 1.4342217445373535
#
# test_70_23189
# CBS result!
# Cost: 1019, Gen nodes: 83, Exp nodes: 42, total CT: 1.4342217445373535
# ICBS result!
# Cost: 1019, Gen nodes: 47, Exp nodes: 27, total CT: 6.9084672927856445
# Learned_CBS results!
# Cost: 1019, Gen_nodes: 53, Exp_nodes: 27, Total CT: 1.3807201385498047
#
# ==============================================================
# Scene: test_70_23199
# CBS total CT: 0.3911170959472656
#
# test_70_23199
# CBS result!
# Cost: 809, Gen nodes: 31, Exp nodes: 16, total CT: 0.3911170959472656
# ICBS result!
# Cost: 809, Gen nodes: 19, Exp nodes: 13, total CT: 1.2323646545410156
# Learned_CBS results!
# Cost: 809, Gen_nodes: 11, Exp_nodes: 6, Total CT: 1.0974929332733154
#
# ==============================================================
# Scene: test_70_23200
# CBS total CT: 2.0781028270721436
#
# test_70_23200
# CBS result!
# Cost: 740, Gen nodes: 135, Exp nodes: 68, total CT: 2.0781028270721436
# ICBS result!
# Cost: 740, Gen nodes: 131, Exp nodes: 68, total CT: 6.552836179733276
# Learned_CBS results!
# Cost: 740, Gen_nodes: 7, Exp_nodes: 4, Total CT: 0.6179344654083252
#
# ==============================================================
# Scene: test_70_23203
# CBS total CT: 0.351773738861084
#
# test_70_23203
# CBS result!
# Cost: 957, Gen nodes: 19, Exp nodes: 10, total CT: 0.351773738861084
# ICBS result!
# Cost: 957, Gen nodes: 11, Exp nodes: 10, total CT: 1.324063777923584
# Learned_CBS results!
# Cost: 957, Gen_nodes: 19, Exp_nodes: 10, Total CT: 0.48693132400512695
#
# ==============================================================
# Scene: test_70_23212
# CBS total CT: 2.7164034843444824
#
# test_70_23212
# CBS result!
# Cost: 1005, Gen nodes: 23, Exp nodes: 12, total CT: 2.7164034843444824
# ICBS result!
# Cost: 1005, Gen nodes: 9, Exp nodes: 8, total CT: 5.4088640213012695
# Learned_CBS results!
# Cost: 1005, Gen_nodes: 21, Exp_nodes: 11, Total CT: 4.086666107177734
#
# ==============================================================
# Scene: test_70_23216
# CBS total CT: 214.05997848510742
#
# test_70_23216
# CBS result!
# Cost: 856, Gen nodes: 20491, Exp nodes: 10246, total CT: 214.05997848510742
# ICBS result!
# Cost: 856, Gen nodes: 36868, Exp nodes: 18437, total CT: 3347.775262117386
# Learned_CBS results!
# Cost: 856, Gen_nodes: 15, Exp_nodes: 8, Total CT: 0.35114383697509766
#
# ==============================================================
# Scene: test_70_23223
# CBS total CT: 0.3982963562011719
#
# test_70_23223
# CBS result!
# Cost: 842, Gen nodes: 35, Exp nodes: 18, total CT: 0.3982963562011719
# ICBS result!
# Cost: 842, Gen nodes: 18, Exp nodes: 11, total CT: 0.9941174983978271
# Learned_CBS results!
# Cost: 842, Gen_nodes: 33, Exp_nodes: 17, Total CT: 0.5022039413452148
#
# ==============================================================
# Scene: test_70_23254
# CBS total CT: 2.1699490547180176
#
# test_70_23254
# CBS result!
# Cost: 797, Gen nodes: 35, Exp nodes: 18, total CT: 2.1699490547180176
# ICBS result!
# Cost: 797, Gen nodes: 25, Exp nodes: 15, total CT: 15.405989646911621
# Learned_CBS results!
# Cost: 797, Gen_nodes: 33, Exp_nodes: 17, Total CT: 2.7457189559936523
#
# ==============================================================
# Scene: test_70_23258
# CBS total CT: 2.189643383026123
#
# test_70_23258
# CBS result!
# Cost: 761, Gen nodes: 113, Exp nodes: 57, total CT: 2.189643383026123
# ICBS result!
# Cost: 761, Gen nodes: 30, Exp nodes: 17, total CT: 1.606968879699707
# Learned_CBS results!
# Cost: 761, Gen_nodes: 57, Exp_nodes: 29, Total CT: 1.5160160064697266
#
# ==============================================================
# Scene: test_70_23259
# CBS total CT: 61.87679839134216
#
# test_70_23259
# CBS result!
# Cost: 782, Gen nodes: 10483, Exp nodes: 5242, total CT: 61.87679839134216
# ICBS result!
# Cost: 782, Gen nodes: 71, Exp nodes: 38, total CT: 2.207958698272705
# Learned_CBS results!
# Cost: 782, Gen_nodes: 2719, Exp_nodes: 1360, Total CT: 20.216046571731567
#
# ==============================================================
# Scene: test_70_23269
# CBS total CT: 1.9029874801635742
#
# test_70_23269
# CBS result!
# Cost: 902, Gen nodes: 165, Exp nodes: 83, total CT: 1.9029874801635742
# ICBS result!
# Cost: 902, Gen nodes: 28, Exp nodes: 16, total CT: 4.5047032833099365
# Learned_CBS results!
# Cost: 902, Gen_nodes: 165, Exp_nodes: 83, Total CT: 2.4132156372070312
#
# ==============================================================
# Scene: test_70_23278
# CBS total CT: 0.39981603622436523
#
# test_70_23278
# CBS result!
# Cost: 784, Gen nodes: 19, Exp nodes: 10, total CT: 0.39981603622436523
# ICBS result!
# Cost: 784, Gen nodes: 16, Exp nodes: 10, total CT: 1.04463529586792
# Learned_CBS results!
# Cost: 784, Gen_nodes: 21, Exp_nodes: 11, Total CT: 0.5909934043884277
#
# ==============================================================
# Scene: test_70_23297
# CBS total CT: 0.8540303707122803
#
# test_70_23297
# CBS result!
# Cost: 886, Gen nodes: 35, Exp nodes: 18, total CT: 0.8540303707122803
# ICBS result!
# Cost: 886, Gen nodes: 18, Exp nodes: 13, total CT: 3.322305679321289
# Learned_CBS results!
# Cost: 886, Gen_nodes: 21, Exp_nodes: 11, Total CT: 1.4522614479064941
#
# ==============================================================
# Scene: test_70_23320
# CBS total CT: 1.7004354000091553
#
# test_70_23320
# CBS result!
# Cost: 816, Gen nodes: 19, Exp nodes: 10, total CT: 1.7004354000091553
# ICBS result!
# Cost: 816, Gen nodes: 11, Exp nodes: 8, total CT: 2.9492874145507812
# Learned_CBS results!
# Cost: 816, Gen_nodes: 19, Exp_nodes: 10, Total CT: 2.8301961421966553
#
# ==============================================================
# Scene: test_70_23336
# CBS total CT: 0.6420550346374512
#
# test_70_23336
# CBS result!
# Cost: 832, Gen nodes: 43, Exp nodes: 22, total CT: 0.6420550346374512
# ICBS result!
# Cost: 832, Gen nodes: 39, Exp nodes: 22, total CT: 1.963599443435669
# Learned_CBS results!
# Cost: 832, Gen_nodes: 43, Exp_nodes: 22, Total CT: 0.8936846256256104
#
# ==============================================================
# Scene: test_70_23337
# CBS total CT: 0.9288241863250732
#
# test_70_23337
# CBS result!
# Cost: 816, Gen nodes: 19, Exp nodes: 10, total CT: 0.9288241863250732
# ICBS result!
# Cost: 816, Gen nodes: 12, Exp nodes: 10, total CT: 4.223084211349487
# Learned_CBS results!
# Cost: 816, Gen_nodes: 13, Exp_nodes: 7, Total CT: 0.7907829284667969
#
# ==============================================================
# Scene: test_70_23356
# CBS total CT: 1.3223435878753662
#
# test_70_23356
# CBS result!
# Cost: 863, Gen nodes: 179, Exp nodes: 90, total CT: 1.3223435878753662
# ICBS result!
# Cost: 863, Gen nodes: 28, Exp nodes: 17, total CT: 1.3982915878295898
# Learned_CBS results!
# Cost: 863, Gen_nodes: 365, Exp_nodes: 183, Total CT: 7.671845197677612
#
# ==============================================================
# Scene: test_70_23358
# CBS total CT: 0.657921552658081
#
# test_70_23358
# CBS result!
# Cost: 859, Gen nodes: 47, Exp nodes: 24, total CT: 0.657921552658081
# ICBS result!
# Cost: 859, Gen nodes: 13, Exp nodes: 9, total CT: 1.1273548603057861
# Learned_CBS results!
# Cost: 859, Gen_nodes: 111, Exp_nodes: 56, Total CT: 1.713876485824585
#
# ==============================================================
# Scene: test_70_23368
# CBS total CT: 0.32418131828308105
#
# test_70_23368
# CBS result!
# Cost: 797, Gen nodes: 29, Exp nodes: 15, total CT: 0.32418131828308105
# ICBS result!
# Cost: 797, Gen nodes: 29, Exp nodes: 17, total CT: 1.484565258026123
# Learned_CBS results!
# Cost: 797, Gen_nodes: 33, Exp_nodes: 17, Total CT: 0.41126012802124023
#
# ==============================================================
# Scene: test_70_23398
# CBS total CT: 0.19001507759094238
#
# test_70_23398
# CBS result!
# Cost: 772, Gen nodes: 27, Exp nodes: 14, total CT: 0.19001507759094238
# ICBS result!
# Cost: 772, Gen nodes: 6, Exp nodes: 5, total CT: 0.260678768157959
# Learned_CBS results!
# Cost: 772, Gen_nodes: 19, Exp_nodes: 10, Total CT: 0.224351167678833
#
# ==============================================================
# Scene: test_70_23405
# CBS total CT: 1.8026540279388428
#
# test_70_23405
# CBS result!
# Cost: 865, Gen nodes: 19, Exp nodes: 10, total CT: 1.8026540279388428
# ICBS result!
# Cost: 865, Gen nodes: 10, Exp nodes: 9, total CT: 3.8455755710601807
# Learned_CBS results!
# Cost: 865, Gen_nodes: 11, Exp_nodes: 6, Total CT: 0.2554295063018799
#
# ==============================================================
# Scene: test_70_23411
# CBS total CT: 1.1149535179138184
#
# test_70_23411
# CBS result!
# Cost: 955, Gen nodes: 67, Exp nodes: 34, total CT: 1.1149535179138184
# ICBS result!
# Cost: 955, Gen nodes: 10, Exp nodes: 7, total CT: 2.100656747817993
# Learned_CBS results!
# Cost: 955, Gen_nodes: 11, Exp_nodes: 6, Total CT: 1.007885217666626
#
# ==============================================================
# Scene: test_70_23417
# CBS total CT: 0.6988365650177002
#
# test_70_23417
# CBS result!
# Cost: 902, Gen nodes: 103, Exp nodes: 52, total CT: 0.6988365650177002
# ICBS result!
# Cost: 902, Gen nodes: 32, Exp nodes: 18, total CT: 1.2916498184204102
# Learned_CBS results!
# Cost: 902, Gen_nodes: 131, Exp_nodes: 66, Total CT: 1.0373079776763916
#
# ==============================================================
# Scene: test_70_23421
# CBS total CT: 9.730648756027222
#
# test_70_23421
# CBS result!
# Cost: 756, Gen nodes: 63, Exp nodes: 32, total CT: 9.730648756027222
# ICBS result!
# Cost: 756, Gen nodes: 12, Exp nodes: 10, total CT: 10.491549968719482
# Learned_CBS results!
# Cost: 756, Gen_nodes: 63, Exp_nodes: 32, Total CT: 13.962244749069214
#
# ==============================================================
# Scene: test_70_23429
# CBS total CT: 2.3322935104370117
#
# test_70_23429
# CBS result!
# Cost: 880, Gen nodes: 27, Exp nodes: 14, total CT: 2.3322935104370117
# ICBS result!
# Cost: 880, Gen nodes: 13, Exp nodes: 11, total CT: 10.315639734268188
# Learned_CBS results!
# Cost: 880, Gen_nodes: 25, Exp_nodes: 13, Total CT: 3.6703710556030273
#
# ==============================================================
# Scene: test_70_23435
# CBS total CT: 1.3093457221984863
#
# test_70_23435
# CBS result!
# Cost: 887, Gen nodes: 43, Exp nodes: 22, total CT: 1.3093457221984863
# ICBS result!
# Cost: 887, Gen nodes: 10, Exp nodes: 8, total CT: 2.0817625522613525
# Learned_CBS results!
# Cost: 887, Gen_nodes: 209, Exp_nodes: 105, Total CT: 10.609306573867798
#
# ==============================================================
# Scene: test_70_23440
# CBS total CT: 61.724234104156494
#
# test_70_23440
# CBS result!
# Cost: 876, Gen nodes: 201, Exp nodes: 101, total CT: 61.724234104156494
# ICBS result!
# Cost: 876, Gen nodes: 14, Exp nodes: 10, total CT: 8.673637628555298
# Learned_CBS results!
# Cost: 876, Gen_nodes: 23, Exp_nodes: 12, Total CT: 6.235713720321655
#
# ==============================================================
# Scene: test_70_23442
# CBS total CT: 1.0687825679779053
#
# test_70_23442
# CBS result!
# Cost: 837, Gen nodes: 163, Exp nodes: 82, total CT: 1.0687825679779053
# ICBS result!
# Cost: 837, Gen nodes: 28, Exp nodes: 18, total CT: 1.4949095249176025
# Learned_CBS results!
# Cost: 837, Gen_nodes: 159, Exp_nodes: 80, Total CT: 1.1452975273132324
#
# ==============================================================
# Scene: test_70_23453
# CBS total CT: 30.819754123687744
#
# test_70_23453
# CBS result!
# Cost: 906, Gen nodes: 2425, Exp nodes: 1213, total CT: 30.819754123687744
# ICBS result!
# Cost: 906, Gen nodes: 54, Exp nodes: 34, total CT: 18.426751852035522
# Learned_CBS results!
# Cost: 906, Gen_nodes: 3763, Exp_nodes: 1882, Total CT: 63.314239740371704
#
# ==============================================================
# Scene: test_70_23458
# CBS total CT: 4.684951543807983
#
# test_70_23458
# CBS result!
# Cost: 1060, Gen nodes: 659, Exp nodes: 330, total CT: 4.684951543807983
# ICBS result!
# Cost: 1060, Gen nodes: 21, Exp nodes: 15, total CT: 3.577118396759033
# Learned_CBS results!
# Cost: 1060, Gen_nodes: 109, Exp_nodes: 55, Total CT: 1.1399683952331543
#
# ==============================================================
# Scene: test_70_23462
# CBS total CT: 0.5334165096282959
#
# test_70_23462
# CBS result!
# Cost: 921, Gen nodes: 27, Exp nodes: 14, total CT: 0.5334165096282959
# ICBS result!
# Cost: 921, Gen nodes: 9, Exp nodes: 7, total CT: 1.135937213897705
# Learned_CBS results!
# Cost: 921, Gen_nodes: 31, Exp_nodes: 16, Total CT: 0.8049323558807373
#
# ==============================================================
# Scene: test_70_23477
# CBS total CT: 58.28522610664368
#
# test_70_23477
# CBS result!
# Cost: 895, Gen nodes: 759, Exp nodes: 380, total CT: 58.28522610664368
# ICBS result!
# Cost: 895, Gen nodes: 16, Exp nodes: 11, total CT: 3.4259495735168457
# Learned_CBS results!
# Cost: 895, Gen_nodes: 475, Exp_nodes: 238, Total CT: 53.10656404495239
#
# ==============================================================
# Scene: test_70_23497
# CBS total CT: 224.62064027786255
#
# test_70_23497
# CBS result!
# Cost: 1027, Gen nodes: 14007, Exp nodes: 7004, total CT: 224.62064027786255
# ICBS result!
# Cost: 1027, Gen nodes: 55, Exp nodes: 31, total CT: 5.641017436981201
# Learned_CBS results!
# Cost: 1027, Gen_nodes: 3193, Exp_nodes: 1597, Total CT: 50.97126579284668
#
# ==============================================================
# Scene: test_70_23512
# CBS total CT: 1.886998176574707
#
# test_70_23512
# CBS result!
# Cost: 901, Gen nodes: 337, Exp nodes: 169, total CT: 1.886998176574707
# ICBS result!
# Cost: 901, Gen nodes: 82, Exp nodes: 45, total CT: 5.107268333435059
# Learned_CBS results!
# Cost: 901, Gen_nodes: 351, Exp_nodes: 176, Total CT: 2.9254202842712402
#
# ==============================================================
# Scene: test_70_23516
# CBS total CT: 1.4985852241516113
#
# test_70_23516
# CBS result!
# Cost: 1051, Gen nodes: 39, Exp nodes: 20, total CT: 1.4985852241516113
# ICBS result!
# Cost: 1051, Gen nodes: 9, Exp nodes: 7, total CT: 1.3561084270477295
# Learned_CBS results!
# Cost: 1051, Gen_nodes: 39, Exp_nodes: 20, Total CT: 2.2475881576538086
#
# ==============================================================
# Scene: test_70_23519
# CBS total CT: 2.2605886459350586
#
# test_70_23519
# CBS result!
# Cost: 795, Gen nodes: 161, Exp nodes: 81, total CT: 2.2605886459350586
# ICBS result!
# Cost: 795, Gen nodes: 17, Exp nodes: 11, total CT: 1.0540623664855957
# Learned_CBS results!
# Cost: 795, Gen_nodes: 161, Exp_nodes: 81, Total CT: 3.0191986560821533
#
# ==============================================================
# Scene: test_70_23524
# CBS total CT: 1.0902340412139893
#
# test_70_23524
# CBS result!
# Cost: 902, Gen nodes: 99, Exp nodes: 50, total CT: 1.0902340412139893
# ICBS result!
# Cost: 902, Gen nodes: 98, Exp nodes: 51, total CT: 5.49615216255188
# Learned_CBS results!
# Cost: 902, Gen_nodes: 189, Exp_nodes: 95, Total CT: 2.952239990234375
#
# ==============================================================
# Scene: test_70_23530
# CBS total CT: 1.1947176456451416
#
# test_70_23530
# CBS result!
# Cost: 922, Gen nodes: 35, Exp nodes: 18, total CT: 1.1947176456451416
# ICBS result!
# Cost: 922, Gen nodes: 16, Exp nodes: 10, total CT: 3.4709510803222656
# Learned_CBS results!
# Cost: 922, Gen_nodes: 37, Exp_nodes: 19, Total CT: 1.6633639335632324
#
# ==============================================================
# Scene: test_70_23531
# CBS total CT: 0.6173925399780273
#
# test_70_23531
# CBS result!
# Cost: 667, Gen nodes: 51, Exp nodes: 26, total CT: 0.6173925399780273
# ICBS result!
# Cost: 667, Gen nodes: 40, Exp nodes: 24, total CT: 2.95068359375
# Learned_CBS results!
# Cost: 667, Gen_nodes: 45, Exp_nodes: 23, Total CT: 0.6447875499725342
#
# ==============================================================
# Scene: test_70_23542
# CBS total CT: 5.786551237106323
#
# test_70_23542
# CBS result!
# Cost: 796, Gen nodes: 859, Exp nodes: 430, total CT: 5.786551237106323
# ICBS result!
# Cost: 796, Gen nodes: 68, Exp nodes: 36, total CT: 2.297438144683838
# Learned_CBS results!
# Cost: 796, Gen_nodes: 221, Exp_nodes: 111, Total CT: 2.2777421474456787
#
# ==============================================================
# Scene: test_70_23544
# CBS total CT: 44.64710283279419
#
# test_70_23544
# CBS result!
# Cost: 925, Gen nodes: 4797, Exp nodes: 2399, total CT: 44.64710283279419
# ICBS result!
# Cost: 925, Gen nodes: 20, Exp nodes: 14, total CT: 3.4859089851379395
# Learned_CBS results!
# Cost: 925, Gen_nodes: 7, Exp_nodes: 4, Total CT: 0.7140464782714844
#
# ==============================================================
# Scene: test_70_23553
# CBS total CT: 13.136086225509644
#
# test_70_23553
# CBS result!
# Cost: 878, Gen nodes: 409, Exp nodes: 205, total CT: 13.136086225509644
# ICBS result!
# Cost: 878, Gen nodes: 33, Exp nodes: 20, total CT: 10.01461410522461
# Learned_CBS results!
# Cost: 878, Gen_nodes: 357, Exp_nodes: 179, Total CT: 15.700553894042969
#
# ==============================================================
# Scene: test_70_23556
# CBS total CT: 43.86937475204468
#
# test_70_23556
# CBS result!
# Cost: 805, Gen nodes: 4347, Exp nodes: 2174, total CT: 43.86937475204468
# ICBS result!
# Cost: 805, Gen nodes: 2093, Exp nodes: 1053, total CT: 106.60936093330383
# Learned_CBS results!
# Cost: 805, Gen_nodes: 2239, Exp_nodes: 1120, Total CT: 34.19888496398926
#
# ==============================================================
# Scene: test_70_23558
# CBS total CT: 2.2014951705932617
#
# test_70_23558
# CBS result!
# Cost: 815, Gen nodes: 27, Exp nodes: 14, total CT: 2.2014951705932617
# ICBS result!
# Cost: 815, Gen nodes: 18, Exp nodes: 14, total CT: 8.012146234512329
# Learned_CBS results!
# Cost: 815, Gen_nodes: 21, Exp_nodes: 11, Total CT: 2.343778133392334
#
# ==============================================================
# Scene: test_70_23561
# CBS total CT: 145.22355723381042
#
# test_70_23561
# CBS result!
# Cost: 797, Gen nodes: 693, Exp nodes: 347, total CT: 145.22355723381042
# ICBS result!
# Cost: 797, Gen nodes: 10, Exp nodes: 8, total CT: 5.74138617515564
# Learned_CBS results!
# Cost: 797, Gen_nodes: 651, Exp_nodes: 326, Total CT: 156.3256049156189
#
# ==============================================================
# Scene: test_70_23602
# CBS total CT: 8.490360498428345
#
# test_70_23602
# CBS result!
# Cost: 903, Gen nodes: 1607, Exp nodes: 804, total CT: 8.490360498428345
# ICBS result!
# Cost: 903, Gen nodes: 94, Exp nodes: 52, total CT: 7.468475341796875
# Learned_CBS results!
# Cost: 903, Gen_nodes: 545, Exp_nodes: 273, Total CT: 4.27861213684082
#
# ==============================================================
# Scene: test_70_23616
# CBS total CT: 2.450836658477783
#
# test_70_23616
# CBS result!
# Cost: 839, Gen nodes: 25, Exp nodes: 13, total CT: 2.450836658477783
# ICBS result!
# Cost: 839, Gen nodes: 9, Exp nodes: 7, total CT: 1.5310087203979492
# Learned_CBS results!
# Cost: 839, Gen_nodes: 35, Exp_nodes: 18, Total CT: 4.419821500778198
#
# ==============================================================
# Scene: test_70_23619
# CBS total CT: 1.5295729637145996
#
# test_70_23619
# CBS result!
# Cost: 1059, Gen nodes: 21, Exp nodes: 11, total CT: 1.5295729637145996
# ICBS result!
# Cost: 1059, Gen nodes: 11, Exp nodes: 11, total CT: 6.512604475021362
# Learned_CBS results!
# Cost: 1059, Gen_nodes: 17, Exp_nodes: 9, Total CT: 2.2886343002319336
#
# ==============================================================
# Scene: test_70_23629
# CBS total CT: 1.3202946186065674
#
# test_70_23629
# CBS result!
# Cost: 939, Gen nodes: 23, Exp nodes: 12, total CT: 1.3202946186065674
# ICBS result!
# Cost: 939, Gen nodes: 12, Exp nodes: 10, total CT: 4.81166410446167
# Learned_CBS results!
# Cost: 939, Gen_nodes: 15, Exp_nodes: 8, Total CT: 0.7979981899261475
#
# ==============================================================
# Scene: test_70_23635
# CBS total CT: 6.962077856063843
#
# test_70_23635
# CBS result!
# Cost: 794, Gen nodes: 41, Exp nodes: 21, total CT: 6.962077856063843
# ICBS result!
# Cost: 794, Gen nodes: 10, Exp nodes: 8, total CT: 3.3559303283691406
# Learned_CBS results!
# Cost: 794, Gen_nodes: 41, Exp_nodes: 21, Total CT: 11.320681810379028
#
# ==============================================================
# Scene: test_70_23638
# CBS total CT: 35.94956183433533
#
# test_70_23638
# CBS result!
# Cost: 957, Gen nodes: 4767, Exp nodes: 2384, total CT: 35.94956183433533
# ICBS result!
# Cost: 957, Gen nodes: 13, Exp nodes: 10, total CT: 2.396033525466919
# Learned_CBS results!
# Cost: 957, Gen_nodes: 463, Exp_nodes: 232, Total CT: 5.269163370132446
#
# ==============================================================
# Scene: test_70_23645
# CBS total CT: 0.6342916488647461
#
# test_70_23645
# CBS result!
# Cost: 1019, Gen nodes: 19, Exp nodes: 10, total CT: 0.6342916488647461
# ICBS result!
# Cost: 1019, Gen nodes: 12, Exp nodes: 12, total CT: 3.732510805130005
# Learned_CBS results!
# Cost: 1019, Gen_nodes: 21, Exp_nodes: 11, Total CT: 0.7186172008514404
#
# ==============================================================
# Scene: test_70_23654
# CBS total CT: 13.371589660644531
#
# test_70_23654
# CBS result!
# Cost: 883, Gen nodes: 997, Exp nodes: 499, total CT: 13.371589660644531
# ICBS result!
# Cost: 883, Gen nodes: 120, Exp nodes: 63, total CT: 6.675174713134766
# Learned_CBS results!
# Cost: 883, Gen_nodes: 635, Exp_nodes: 318, Total CT: 14.12949013710022
#
# ==============================================================
# Scene: test_70_23664
# CBS total CT: 0.7023687362670898
#
# test_70_23664
# CBS result!
# Cost: 841, Gen nodes: 21, Exp nodes: 11, total CT: 0.7023687362670898
# ICBS result!
# Cost: 841, Gen nodes: 14, Exp nodes: 11, total CT: 3.5673344135284424
# Learned_CBS results!
# Cost: 841, Gen_nodes: 21, Exp_nodes: 11, Total CT: 1.2748329639434814
#
# ==============================================================
# Scene: test_70_23675
# CBS total CT: 1.8283514976501465
#
# test_70_23675
# CBS result!
# Cost: 915, Gen nodes: 151, Exp nodes: 76, total CT: 1.8283514976501465
# ICBS result!
# Cost: 915, Gen nodes: 5, Exp nodes: 4, total CT: 0.39017319679260254
# Learned_CBS results!
# Cost: 915, Gen_nodes: 17, Exp_nodes: 9, Total CT: 0.46636533737182617
#
# ==============================================================
# Scene: test_70_23683
# CBS total CT: 2.582184076309204
#
# test_70_23683
# CBS result!
# Cost: 976, Gen nodes: 139, Exp nodes: 70, total CT: 2.582184076309204
# ICBS result!
# Cost: 976, Gen nodes: 133, Exp nodes: 70, total CT: 9.697715282440186
# Learned_CBS results!
# Cost: 976, Gen_nodes: 139, Exp_nodes: 70, Total CT: 3.8554654121398926
#
# ==============================================================
# Scene: test_70_23704
# CBS total CT: 1.4613611698150635
#
# test_70_23704
# CBS result!
# Cost: 885, Gen nodes: 23, Exp nodes: 12, total CT: 1.4613611698150635
# ICBS result!
# Cost: 885, Gen nodes: 12, Exp nodes: 12, total CT: 9.35524606704712
# Learned_CBS results!
# Cost: 885, Gen_nodes: 15, Exp_nodes: 8, Total CT: 2.115532159805298
#
# ==============================================================
# Scene: test_70_23718
# CBS total CT: 0.40039753913879395
#
# test_70_23718
# CBS result!
# Cost: 816, Gen nodes: 19, Exp nodes: 10, total CT: 0.40039753913879395
# ICBS result!
# Cost: 816, Gen nodes: 10, Exp nodes: 7, total CT: 0.9192216396331787
# Learned_CBS results!
# Cost: 816, Gen_nodes: 17, Exp_nodes: 9, Total CT: 0.7242953777313232
#
# ==============================================================
# Scene: test_70_23723
# CBS total CT: 80.06251454353333
#
# ==============================================================
# Scene: test_70_23724
# CBS total CT: 3.716775417327881
#
# test_70_23724
# CBS result!
# ...
# Scene: test_70_24722
# CBS total CT: 8.091975450515747
#
# test_70_24722
# CBS result!
# Cost: 922, Gen nodes: 343, Exp nodes: 172, total CT: 8.091975450515747
# ICBS result!
# Cost: 922, Gen nodes: 14, Exp nodes: 11, total CT: 4.614460468292236
# Learned_CBS results!
# Cost: 922, Gen_nodes: 43, Exp_nodes: 22, Total CT: 1.950380802154541
#
# ==============================================================
# Scene: test_70_24727
# CBS total CT: 1.200291395187378
#
# test_70_24727
# CBS result!
# Cost: 944, Gen nodes: 19, Exp nodes: 10, total CT: 1.200291395187378
# ICBS result!
# Cost: 944, Gen nodes: 11, Exp nodes: 11, total CT: 5.321669101715088
# Learned_CBS results!
# Cost: 944, Gen_nodes: 23, Exp_nodes: 12, Total CT: 1.4148445129394531
#
# ==============================================================
# Scene: test_70_24734
# CBS total CT: 1.4922449588775635
#
# test_70_24734
# CBS result!
# Cost: 804, Gen nodes: 23, Exp nodes: 12, total CT: 1.4922449588775635
# ICBS result!
# Cost: 804, Gen nodes: 13, Exp nodes: 10, total CT: 6.4230523109436035
# Learned_CBS results!
# Cost: 804, Gen_nodes: 19, Exp_nodes: 10, Total CT: 1.7976436614990234
#
# ==============================================================
# Scene: test_70_24749
# CBS total CT: 0.9443998336791992
#
# test_70_24749
# CBS result!
# Cost: 983, Gen nodes: 31, Exp nodes: 16, total CT: 0.9443998336791992
# ICBS result!
# Cost: 983, Gen nodes: 10, Exp nodes: 8, total CT: 2.819380521774292
# Learned_CBS results!
# Cost: 983, Gen_nodes: 25, Exp_nodes: 13, Total CT: 1.1687662601470947
#
# ==============================================================
# Scene: test_70_24754
# CBS total CT: 6.712562799453735
#
# test_70_24754
# CBS result!
# Cost: 926, Gen nodes: 517, Exp nodes: 259, total CT: 6.712562799453735
# ICBS result!
# Cost: 926, Gen nodes: 259, Exp nodes: 132, total CT: 12.4355788230896
# Learned_CBS results!
# Cost: 926, Gen_nodes: 2359, Exp_nodes: 1180, Total CT: 27.135040521621704
#
# ==============================================================
# Scene: test_70_24768
# CBS total CT: 0.6805963516235352
#
# test_70_24768
# CBS result!
# Cost: 808, Gen nodes: 19, Exp nodes: 10, total CT: 0.6805963516235352
# ICBS result!
# Cost: 808, Gen nodes: 11, Exp nodes: 9, total CT: 2.124910831451416
# Learned_CBS results!
# Cost: 808, Gen_nodes: 19, Exp_nodes: 10, Total CT: 0.7060143947601318
#
# ==============================================================
# Scene: test_70_24776
# CBS total CT: 2.9017465114593506
#
# ==============================================================
# Scene: test_70_24777
# CBS total CT: 1.7829201221466064
#
# test_70_24777
# CBS result!
# Cost: 871, Gen nodes: 23, Exp nodes: 12, total CT: 1.7829201221466064
# ICBS result!
# Cost: 871, Gen nodes: 9, Exp nodes: 8, total CT: 4.322749853134155
# Learned_CBS results!
# Cost: 871, Gen_nodes: 13, Exp_nodes: 7, Total CT: 0.9657731056213379
#
# ==============================================================
# Scene: test_70_24779
# CBS total CT: 0.7967298030853271
#
# test_70_24779
# CBS result!
# Cost: 918, Gen nodes: 49, Exp nodes: 25, total CT: 0.7967298030853271
# ICBS result!
# Cost: 918, Gen nodes: 16, Exp nodes: 12, total CT: 2.131824254989624
# Learned_CBS results!
# Cost: 918, Gen_nodes: 13, Exp_nodes: 7, Total CT: 0.4520854949951172
#
# ==============================================================
# Scene: test_70_24785
# CBS total CT: 1.0644328594207764
#
# test_70_24785
# CBS result!
# Cost: 1051, Gen nodes: 57, Exp nodes: 29, total CT: 1.0644328594207764
# ICBS result!
# Cost: 1051, Gen nodes: 21, Exp nodes: 13, total CT: 2.30896258354187
# Learned_CBS results!
# Cost: 1051, Gen_nodes: 59, Exp_nodes: 30, Total CT: 1.39497971534729
#
# ==============================================================
# Scene: test_70_24793
# CBS total CT: 9.579481601715088
#
# test_70_24793
# CBS result!
# Cost: 825, Gen nodes: 1235, Exp nodes: 618, total CT: 9.579481601715088
# ICBS result!
# Cost: 825, Gen nodes: 74, Exp nodes: 41, total CT: 9.525952577590942
# Learned_CBS results!
# Cost: 825, Gen_nodes: 2397, Exp_nodes: 1199, Total CT: 19.935975074768066
#
# ==============================================================
# Scene: test_70_24801
# CBS total CT: 4.11129093170166
#
# test_70_24801
# CBS result!
# Cost: 786, Gen nodes: 117, Exp nodes: 59, total CT: 4.11129093170166
# ICBS result!
# Cost: 786, Gen nodes: 13, Exp nodes: 11, total CT: 4.12830114364624
# Learned_CBS results!
# Cost: 786, Gen_nodes: 103, Exp_nodes: 52, Total CT: 3.9499785900115967
#
# ==============================================================
# Scene: test_70_24802
# CBS total CT: 1.3211071491241455
#
# test_70_24802
# CBS result!
# Cost: 889, Gen nodes: 23, Exp nodes: 12, total CT: 1.3211071491241455
# ICBS result!
# Cost: 889, Gen nodes: 12, Exp nodes: 11, total CT: 6.493471145629883
# Learned_CBS results!
# Cost: 889, Gen_nodes: 23, Exp_nodes: 12, Total CT: 1.7963371276855469
#
# ==============================================================
# Scene: test_70_24806
# CBS total CT: 1.2163832187652588
#
# test_70_24806
# CBS result!
# Cost: 809, Gen nodes: 19, Exp nodes: 10, total CT: 1.2163832187652588
# ICBS result!
# Cost: 809, Gen nodes: 10, Exp nodes: 8, total CT: 3.829969644546509
# Learned_CBS results!
# Cost: 809, Gen_nodes: 11, Exp_nodes: 6, Total CT: 0.8946821689605713
#
# ==============================================================
# Scene: test_70_24814
# CBS total CT: 3.7345519065856934
#
# test_70_24814
# CBS result!
# Cost: 977, Gen nodes: 365, Exp nodes: 183, total CT: 3.7345519065856934
# ICBS result!
# Cost: 977, Gen nodes: 47, Exp nodes: 28, total CT: 5.125040531158447
# Learned_CBS results!
# Cost: 977, Gen_nodes: 365, Exp_nodes: 183, Total CT: 3.786801815032959
#
# ==============================================================
# Scene: test_70_24823
# CBS total CT: 1.127882719039917
#
# test_70_24823
# CBS result!
# Cost: 882, Gen nodes: 87, Exp nodes: 44, total CT: 1.127882719039917
# ICBS result!
# Cost: 882, Gen nodes: 16, Exp nodes: 10, total CT: 1.5637362003326416
# Learned_CBS results!
# Cost: 882, Gen_nodes: 173, Exp_nodes: 87, Total CT: 2.606837034225464
#
# ==============================================================
# Scene: test_70_24832
# CBS total CT: 2.145373821258545
#
# test_70_24832
# CBS result!
# Cost: 735, Gen nodes: 247, Exp nodes: 124, total CT: 2.145373821258545
# ICBS result!
# Cost: 735, Gen nodes: 93, Exp nodes: 50, total CT: 4.8886213302612305
# Learned_CBS results!
# Cost: 735, Gen_nodes: 247, Exp_nodes: 124, Total CT: 2.4303479194641113
#
# ==============================================================
# Scene: test_70_24836
# CBS total CT: 0.5679852962493896
#
# test_70_24836
# CBS result!
# Cost: 866, Gen nodes: 49, Exp nodes: 25, total CT: 0.5679852962493896
# ICBS result!
# Cost: 866, Gen nodes: 46, Exp nodes: 25, total CT: 1.4672584533691406
# Learned_CBS results!
# Cost: 866, Gen_nodes: 49, Exp_nodes: 25, Total CT: 0.6885535717010498
#
# ==============================================================
# Scene: test_70_24837
# CBS total CT: 6.198439598083496
#
# test_70_24837
# CBS result!
# Cost: 699, Gen nodes: 125, Exp nodes: 63, total CT: 6.198439598083496
# ICBS result!
# Cost: 699, Gen nodes: 24, Exp nodes: 14, total CT: 2.9897007942199707
# Learned_CBS results!
# Cost: 699, Gen_nodes: 365, Exp_nodes: 183, Total CT: 22.068674564361572
#
# ==============================================================
# Scene: test_70_24842
# CBS total CT: 0.6613318920135498
#
# test_70_24842
# CBS result!
# Cost: 772, Gen nodes: 19, Exp nodes: 10, total CT: 0.6613318920135498
# ICBS result!
# Cost: 772, Gen nodes: 16, Exp nodes: 10, total CT: 1.7381961345672607
# Learned_CBS results!
# Cost: 772, Gen_nodes: 27, Exp_nodes: 14, Total CT: 0.9093866348266602
#
# ==============================================================
# Scene: test_70_24856
# CBS total CT: 24.762255430221558
#
# test_70_24856
# CBS result!
# Cost: 626, Gen nodes: 7173, Exp nodes: 3587, total CT: 24.762255430221558
# ICBS result!
# Cost: 626, Gen nodes: 99, Exp nodes: 52, total CT: 2.3589091300964355
# Learned_CBS results!
# Cost: 626, Gen_nodes: 1849, Exp_nodes: 925, Total CT: 7.529163122177124
#
# ==============================================================
# Scene: test_70_24861
# CBS total CT: 2.3807737827301025
#
# test_70_24861
# CBS result!
# Cost: 871, Gen nodes: 321, Exp nodes: 161, total CT: 2.3807737827301025
# ICBS result!
# Cost: 871, Gen nodes: 53, Exp nodes: 29, total CT: 2.142162799835205
# Learned_CBS results!
# Cost: 871, Gen_nodes: 161, Exp_nodes: 81, Total CT: 1.4414339065551758
#
# ==============================================================
# Scene: test_70_24878
# CBS total CT: 2.8477516174316406
#
# test_70_24878
# CBS result!
# Cost: 747, Gen nodes: 51, Exp nodes: 26, total CT: 2.8477516174316406
# ICBS result!
# Cost: 747, Gen nodes: 40, Exp nodes: 23, total CT: 5.257725954055786
# Learned_CBS results!
# Cost: 747, Gen_nodes: 17, Exp_nodes: 9, Total CT: 1.585052490234375
#
# ==============================================================
# Scene: test_70_24885
# CBS total CT: 2.2893006801605225
#
# test_70_24885
# CBS result!
# Cost: 904, Gen nodes: 163, Exp nodes: 82, total CT: 2.2893006801605225
# ICBS result!
# Cost: 904, Gen nodes: 16, Exp nodes: 12, total CT: 3.9419288635253906
# Learned_CBS results!
# Cost: 904, Gen_nodes: 161, Exp_nodes: 81, Total CT: 2.6904304027557373
#
# ==============================================================
# Scene: test_70_24887
# CBS total CT: 1.7342305183410645
#
# test_70_24887
# CBS result!
# Cost: 921, Gen nodes: 23, Exp nodes: 12, total CT: 1.7342305183410645
# ICBS result!
# Cost: 921, Gen nodes: 14, Exp nodes: 12, total CT: 6.536921977996826
# Learned_CBS results!
# Cost: 921, Gen_nodes: 25, Exp_nodes: 13, Total CT: 2.8221070766448975
#
# ==============================================================
# Scene: test_70_24896
# CBS total CT: 1.4850504398345947
#
# test_70_24896
# CBS result!
# Cost: 928, Gen nodes: 19, Exp nodes: 10, total CT: 1.4850504398345947
# ICBS result!
# Cost: 928, Gen nodes: 10, Exp nodes: 9, total CT: 4.69275164604187
# Learned_CBS results!
# Cost: 928, Gen_nodes: 11, Exp_nodes: 6, Total CT: 1.9145593643188477
#
# ==============================================================
# Scene: test_70_24901
# CBS total CT: 5.377443552017212
#
# test_70_24901
# CBS result!
# Cost: 999, Gen nodes: 127, Exp nodes: 64, total CT: 5.377443552017212
# ICBS result!
# Cost: 999, Gen nodes: 58, Exp nodes: 35, total CT: 18.676565170288086
# Learned_CBS results!
# Cost: 999, Gen_nodes: 103, Exp_nodes: 52, Total CT: 3.0859532356262207
#
# ==============================================================
# Scene: test_70_24915
# CBS total CT: 3.148244857788086
#
# test_70_24915
# CBS result!
# Cost: 948, Gen nodes: 201, Exp nodes: 101, total CT: 3.148244857788086
# ICBS result!
# Cost: 948, Gen nodes: 21, Exp nodes: 15, total CT: 3.3720927238464355
# Learned_CBS results!
# Cost: 948, Gen_nodes: 101, Exp_nodes: 51, Total CT: 2.3212549686431885
#
# ==============================================================
# Scene: test_70_24920
# CBS total CT: 2.956273317337036
#
# test_70_24920
# CBS result!
# Cost: 870, Gen nodes: 395, Exp nodes: 198, total CT: 2.956273317337036
# ICBS result!
# Cost: 870, Gen nodes: 136, Exp nodes: 72, total CT: 11.835203170776367
# Learned_CBS results!
# Cost: 870, Gen_nodes: 395, Exp_nodes: 198, Total CT: 3.764012098312378
#
# ==============================================================
# Scene: test_70_24923
# CBS total CT: 1.6937665939331055
#
# test_70_24923
# CBS result!
# Cost: 994, Gen nodes: 21, Exp nodes: 11, total CT: 1.6937665939331055
# ICBS result!
# Cost: 994, Gen nodes: 14, Exp nodes: 11, total CT: 5.919269561767578
# Learned_CBS results!
# Cost: 994, Gen_nodes: 15, Exp_nodes: 8, Total CT: 1.6111900806427002
#
# ==============================================================
# Scene: test_70_24926
# CBS total CT: 0.5164661407470703
#
# test_70_24926
# CBS result!
# Cost: 836, Gen nodes: 45, Exp nodes: 23, total CT: 0.5164661407470703
# ICBS result!
# Cost: 836, Gen nodes: 21, Exp nodes: 13, total CT: 1.4582147598266602
# Learned_CBS results!
# Cost: 836, Gen_nodes: 39, Exp_nodes: 20, Total CT: 0.5369882583618164
#
# ==============================================================
# Scene: test_70_24927
# CBS total CT: 0.3513219356536865
#
# test_70_24927
# CBS result!
# Cost: 819, Gen nodes: 19, Exp nodes: 10, total CT: 0.3513219356536865
# ICBS result!
# Cost: 819, Gen nodes: 9, Exp nodes: 6, total CT: 0.8833565711975098
# Learned_CBS results!
# Cost: 819, Gen_nodes: 99, Exp_nodes: 50, Total CT: 2.1862542629241943
#
# ==============================================================
# Scene: test_70_24929
# CBS total CT: 0.39272546768188477
#
# test_70_24929
# CBS result!
# Cost: 831, Gen nodes: 19, Exp nodes: 10, total CT: 0.39272546768188477
# ICBS result!
# Cost: 831, Gen nodes: 12, Exp nodes: 10, total CT: 1.7281088829040527
# Learned_CBS results!
# Cost: 831, Gen_nodes: 13, Exp_nodes: 7, Total CT: 0.5092220306396484
#
# ==============================================================
# Scene: test_70_24930
# CBS total CT: 0.828418493270874
#
# test_70_24930
# CBS result!
# Cost: 830, Gen nodes: 21, Exp nodes: 11, total CT: 0.828418493270874
# ICBS result!
# Cost: 830, Gen nodes: 16, Exp nodes: 11, total CT: 2.407670736312866
# Learned_CBS results!
# Cost: 830, Gen_nodes: 13, Exp_nodes: 7, Total CT: 1.019918441772461
#
# ==============================================================
# Scene: test_70_24933
# CBS total CT: 6.893032789230347
#
# test_70_24933
# CBS result!
# Cost: 872, Gen nodes: 519, Exp nodes: 260, total CT: 6.893032789230347
# ICBS result!
# Cost: 872, Gen nodes: 131, Exp nodes: 68, total CT: 6.092947959899902
# Learned_CBS results!
# Cost: 872, Gen_nodes: 521, Exp_nodes: 261, Total CT: 10.045831441879272
#
# ==============================================================
# Scene: test_70_24941
# CBS total CT: 1.0373990535736084
#
# test_70_24941
# CBS result!
# Cost: 987, Gen nodes: 19, Exp nodes: 10, total CT: 1.0373990535736084
# ICBS result!
# Cost: 987, Gen nodes: 11, Exp nodes: 10, total CT: 3.888242483139038
# Learned_CBS results!
# Cost: 987, Gen_nodes: 19, Exp_nodes: 10, Total CT: 2.8946034908294678
#
# ==============================================================
# Scene: test_70_24951
# CBS total CT: 1.502655029296875
#
# test_70_24951
# CBS result!
# Cost: 867, Gen nodes: 25, Exp nodes: 13, total CT: 1.502655029296875
# ICBS result!
# Cost: 867, Gen nodes: 8, Exp nodes: 6, total CT: 1.5313024520874023
# Learned_CBS results!
# Cost: 867, Gen_nodes: 11, Exp_nodes: 6, Total CT: 0.9366409778594971
#
# ==============================================================
# Scene: test_70_24957
# CBS total CT: 6.764261484146118
#
# test_70_24957
# CBS result!
# Cost: 666, Gen nodes: 497, Exp nodes: 249, total CT: 6.764261484146118
# ICBS result!
# Cost: 666, Gen nodes: 11, Exp nodes: 8, total CT: 0.7901051044464111
# Learned_CBS results!
# Cost: 666, Gen_nodes: 7, Exp_nodes: 4, Total CT: 0.24680018424987793
#
# ==============================================================
# Scene: test_70_24960
# CBS total CT: 1.1214711666107178
#
# test_70_24960
# CBS result!
# Cost: 685, Gen nodes: 145, Exp nodes: 73, total CT: 1.1214711666107178
# ICBS result!
# Cost: 685, Gen nodes: 23, Exp nodes: 13, total CT: 1.3978629112243652
# Learned_CBS results!
# Cost: 685, Gen_nodes: 145, Exp_nodes: 73, Total CT: 1.4953303337097168
#
# ==============================================================
# Scene: test_70_24967
# CBS total CT: 51.722163438797
#
# test_70_24967
# CBS result!
# Cost: 890, Gen nodes: 2523, Exp nodes: 1262, total CT: 51.722163438797
# ICBS result!
# Cost: 890, Gen nodes: 11, Exp nodes: 9, total CT: 3.240104913711548
# Learned_CBS results!
# Cost: 890, Gen_nodes: 2073, Exp_nodes: 1037, Total CT: 66.1164915561676
#
# ==============================================================
# Scene: test_70_24974
# CBS total CT: 0.4579603672027588
#
# test_70_24974
# CBS result!
# Cost: 821, Gen nodes: 39, Exp nodes: 20, total CT: 0.4579603672027588
# ICBS result!
# Cost: 821, Gen nodes: 17, Exp nodes: 11, total CT: 1.4967563152313232
# Learned_CBS results!
# Cost: 821, Gen_nodes: 33, Exp_nodes: 17, Total CT: 0.33913278579711914
#
# ==============================================================
# Scene: test_70_24987
# CBS total CT: 0.49132347106933594
#
# test_70_24987
# CBS result!
# Cost: 1088, Gen nodes: 21, Exp nodes: 11, total CT: 0.49132347106933594
# ICBS result!
# Cost: 1088, Gen nodes: 11, Exp nodes: 11, total CT: 2.8635406494140625
# Learned_CBS results!
# Cost: 1088, Gen_nodes: 15, Exp_nodes: 8, Total CT: 0.5358808040618896

# %%
import glob

# %%
# /home/railab/Workspace/CCBS/Train_results/Overfitting_test_69/cbs_results/test_69_110.txt
train_result_file_list = sorted(glob.glob("/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/*.txt"))
print(len(train_result_file_list))
train_result_file_list
# Out:
# 311
# ['/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22606.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22628.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22629.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22630.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22632.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22637.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22639.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22642.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22650.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22660.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22664.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22684.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22686.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22692.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22704.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22710.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22711.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22713.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22718.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22730.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22732.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22747.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22760.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22769.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22772.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22779.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22781.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22787.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22792.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22793.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22817.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22824.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22837.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22854.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22859.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22864.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22879.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22894.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22900.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22904.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22911.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22912.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22921.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22928.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22937.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22943.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22945.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22946.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22951.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22954.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22955.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22961.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22968.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22973.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22974.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22977.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22988.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_22998.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23016.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23018.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23026.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23030.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23031.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23033.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23046.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23051.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23057.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23062.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23079.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23082.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23089.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23098.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23101.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23113.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23122.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23126.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23147.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23148.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23171.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23176.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23189.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23199.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23200.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23203.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23212.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23216.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23223.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23254.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23258.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23259.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23269.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23278.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23297.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23320.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23336.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23337.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23356.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23358.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23368.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23398.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23405.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23411.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23417.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23421.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23429.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23435.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23440.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23442.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23453.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23458.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23462.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23477.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23497.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23512.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23516.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23519.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23524.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23530.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23531.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23542.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23544.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23553.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23556.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23558.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23561.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23602.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23616.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23619.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23629.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23635.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23638.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23645.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23654.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23664.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23675.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23683.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23704.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23718.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23724.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23726.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23743.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23750.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23761.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23766.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23770.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23791.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23825.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23848.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23850.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23855.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23856.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23858.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23861.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23867.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23878.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23885.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23893.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23899.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23900.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23902.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23915.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23917.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23935.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23938.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23948.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23954.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23962.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23967.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23968.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23975.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23983.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23987.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_23993.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24000.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24003.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24009.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24019.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24020.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24022.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24027.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24028.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24032.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24054.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24060.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24064.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24068.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24069.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24079.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24083.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24090.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24105.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24108.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24111.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24123.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24125.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24127.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24128.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24131.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24142.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24145.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24157.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24181.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24195.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24201.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24205.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24217.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24220.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24224.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24228.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24241.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24269.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24273.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24277.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24279.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24286.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24293.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24301.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24309.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24318.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24323.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24336.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24340.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24342.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24364.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24385.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24393.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24411.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24418.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24422.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24439.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24445.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24456.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24463.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24464.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24469.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24476.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24480.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24503.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24507.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24513.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24517.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24520.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24526.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24534.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24535.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24541.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24553.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24558.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24571.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24576.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24586.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24587.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24591.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24598.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24603.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24607.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24621.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24630.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24631.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24654.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24666.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24671.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24676.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24678.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24679.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24684.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24690.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24691.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24703.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24704.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24722.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24727.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24734.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24749.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24754.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24768.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24777.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24779.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24785.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24793.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24801.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24802.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24806.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24814.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24823.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24832.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24836.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24837.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24842.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24856.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24861.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24878.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24885.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24887.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24896.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24901.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24915.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24920.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24923.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24926.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24927.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24929.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24930.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24933.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24941.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24951.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24957.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24960.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24967.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24974.txt',
#  '/home/railab/Workspace/CCBS/Results/Train_results/Overfitting_test_70/learned_cbs_results/test_70_24987.txt']

# %%
total_cbs_cost = 0
total_cbs_gen_nodes = 0
total_cbs_exp_nodes = 0
total_cbs_CT = 0

total_icbs_cost = 0
total_icbs_gen_nodes = 0
total_icbs_exp_nodes = 0
total_icbs_CT = 0

total_lcbs_cost = 0
total_lcbs_gen_nodes = 0
total_lcbs_exp_nodes = 0
total_lcbs_CT = 0

more_CT_cnt = 0

for train_result_file in train_result_file_list:
    f = open(train_result_file, 'r')
    result = f.readlines()
    f.close()

    # print(result)

    # print(train_result_file)

    cbs_result = result[2]
    icbs_result = result[4]
    lcbs_result = result[6]

    cbs_cost = int(cbs_result.split(", ")[0].split(": ")[-1])
    cbs_gen_nodes = int(cbs_result.split(", ")[1].split(": ")[-1])
    cbs_exp_nodes = int(cbs_result.split(", ")[2].split(": ")[-1])
    cbs_total_CT = float(cbs_result.split(", ")[3].split(": ")[-1])

    icbs_cost = int(icbs_result.split(", ")[0].split(": ")[-1])
    icbs_gen_nodes = int(icbs_result.split(", ")[1].split(": ")[-1])
    icbs_exp_nodes = int(icbs_result.split(", ")[2].split(": ")[-1])
    icbs_total_CT = float(icbs_result.split(", ")[3].split(": ")[-1])

    lcbs_cost = int(lcbs_result.split(", ")[0].split(": ")[-1])
    lcbs_gen_nodes = int(lcbs_result.split(", ")[1].split(": ")[-1])
    lcbs_exp_nodes = int(lcbs_result.split(", ")[2].split(": ")[-1])
    lcbs_total_CT = float(lcbs_result.split(", ")[3].split(": ")[-1])

    # if cbs_total_CT < lcbs_total_CT:
    #     print("....?")
    #     print("CBS:", cbs_total_CT)
    #     print("LCBS:", lcbs_total_CT)

    #     more_CT_cnt += 1

    total_cbs_cost += cbs_cost
    total_cbs_gen_nodes += cbs_gen_nodes
    total_cbs_exp_nodes += cbs_exp_nodes
    total_cbs_CT += cbs_total_CT

    total_icbs_cost += icbs_cost
    total_icbs_gen_nodes += icbs_gen_nodes
    total_icbs_exp_nodes += icbs_exp_nodes
    total_icbs_CT += icbs_total_CT

    total_lcbs_cost += lcbs_cost
    total_lcbs_gen_nodes += lcbs_gen_nodes
    total_lcbs_exp_nodes += lcbs_exp_nodes
    total_lcbs_CT += lcbs_total_CT

avg_cbs_cost = total_cbs_cost / len(train_result_file_list)
avg_cbs_gen_nodes = total_cbs_gen_nodes / len(train_result_file_list)
avg_cbs_exp_nodes = total_cbs_exp_nodes / len(train_result_file_list)
avg_cbs_CT = total_cbs_CT / len(train_result_file_list)

avg_icbs_cost = total_icbs_cost / len(train_result_file_list)
avg_icbs_gen_nodes = total_icbs_gen_nodes / len(train_result_file_list)
avg_icbs_exp_nodes = total_icbs_exp_nodes / len(train_result_file_list)
avg_icbs_CT = total_icbs_CT / len(train_result_file_list)

avg_lcbs_cost = total_lcbs_cost / len(train_result_file_list)
avg_lcbs_gen_nodes = total_lcbs_gen_nodes / len(train_result_file_list)
avg_lcbs_exp_nodes = total_lcbs_exp_nodes / len(train_result_file_list)
avg_lcbs_CT = total_lcbs_CT / len(train_result_file_list)

print("CBS\nAvg cost: {}, Avg gen nodes: {}, Avg exp nodes: {}, Avg CT: {}".format(avg_cbs_cost, avg_cbs_gen_nodes, avg_cbs_exp_nodes, avg_cbs_CT))
print("\nICBS\nAvg cost: {}, Avg gen nodes: {}, Avg exp nodes: {}, Avg CT: {}".format(avg_icbs_cost, avg_icbs_gen_nodes, avg_icbs_exp_nodes, avg_icbs_CT))
print("\nLCBS\nAvg cost: {}, Avg gen nodes: {}, Avg exp nodes: {}, Avg CT: {}".format(avg_lcbs_cost, avg_lcbs_gen_nodes, avg_lcbs_exp_nodes, avg_lcbs_CT))
# Out:
# CBS
# Avg cost: 868.652733118971, Avg gen nodes: 1074.2861736334405, Avg exp nodes: 537.6430868167203, Avg CT: 12.722630627285628
#
# ICBS
# Avg cost: 868.6559485530547, Avg gen nodes: 173.39871382636656, Avg exp nodes: 90.02572347266882, Avg CT: 19.309302523971756
#
# LCBS
# Avg cost: 868.652733118971, Avg gen nodes: 444.459807073955, Avg exp nodes: 222.7299035369775, Avg CT: 7.660848543191646
# 0

# %% [markdown]
# PRIMAL

# %%
primal_result_paths = sorted(glob.glob("/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/*.txt"))
print(primal_result_paths)
# Out:
# ['/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22606.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22628.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22629.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22630.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22632.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22637.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22639.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22642.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22650.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22660.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22664.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22684.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22686.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22692.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22704.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22710.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22711.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22713.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22718.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22730.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22732.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22747.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22760.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22769.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22772.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22779.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22781.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22787.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22792.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22793.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22817.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22824.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22837.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22854.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22859.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22864.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22879.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22894.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22900.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22904.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22911.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22912.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22921.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22928.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22937.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22943.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22945.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/test_70_22946.txt', '/home/railab/Workspace/CCBS/Results/Baselines/PRIMAL/test_70/t ...

# %%
optimal_cnt = 0
total_CT = 0
fail_cnt = 0

for primal_result_file in primal_result_paths:
    f = open(primal_result_file, 'r')
    primal_result = f.readlines()
    f.close()

    scene_name = primal_result_file.split("/")[-1][:-4]
    cbs_path = "/home/railab/Workspace/CCBS/Results/Making_heatmap/test_70/bigger_heatmap/nodes_dec/test_10/"
    cbs_result_path = cbs_path + scene_name + "_result.txt"

    f = open(cbs_result_path, 'r')
    cbs_result = f.readlines()
    f.close()


    primal_cost = int(primal_result[0].split(", ")[0].split(": ")[-1])
    primal_Done = int(primal_result[0].split(", ")[1].split(": ")[-1])
    primal_CT = float(primal_result[0].split(", ")[-1].split(": ")[-1])

    if primal_Done != 20:
        fail_cnt += 1
        continue

    cbs_cost = int(cbs_result[2].split(', ')[0].split(": ")[-1])
    
    if primal_cost == cbs_cost:
        optimal_cnt += 1
    
    total_CT += primal_CT

avg_primal_CT = total_CT/len(primal_result_paths)
success_rate = (len(primal_result_paths) - fail_cnt) / len(primal_result_paths) * 100
optimal_rate = optimal_cnt / len(primal_result_paths) * 100

print("64x64 result\nComputation time: {}, Success rate: {}, Optimal rate: {}".format(avg_primal_CT, success_rate, optimal_rate))
# Out:
# 64x64 result
# Computation time: 6.118571770304009, Success rate: 97.47634069400631, Optimal rate: 0.0
